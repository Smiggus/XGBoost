# %% [markdown]
# # Initial Example
# Below is an initail example of the XGBoost algo. This is a simple example to get you started with the XGBoost algo. Try it first, then you can modify it to get better results.
#
# Need to input SPY daily data for the last 2 years (2021-2022) and test against 2023 close prices.
# Start with just PriceVol then modify to use TA and other factors.
# Consider using daily returns instead of prices.
#
# Currently, the algo uses the databento sql pipeline to help pull, although date does need to be converted to a datetime object to work with the method.

# %%
import xgboost as xgb

# %%
ticker_list = ['AAPL', 'MSFT', 'NVDA',  # Technology
    'AMZN', 'TSLA', 'HD',  # Consumer Discretionary
    'UNH', 'JNJ', 'LLY',  # Healthcare
    'JPM', 'BAC', 'WFC',  # Financials
    'XOM', 'CVX', 'COP',  # Energy
    'PG', 'KO', 'PEP',  # Consumer Staples
    'BA', 'CAT', 'UPS',  # Industrials
    'LIN', 'APD', 'SHW',  # Materials
    'PLD', 'AMT', 'CCI',  # Real Estate
    'NEE', 'DUK', 'SO',  # Utilities
]

# %%
# Download the Data from Postgres
import databento_sql as dbs

#ticker_list = ['SPY']
for ticker in ticker_list:
    dbs.download_and_append_data(ticker, '2019-01-01', '2023-12-31', frequency='daily')
# Out:
# Ticker AAPL already up-to-date
# data/equity/usa/daily/aapl.csv has been successfully zipped into data/equity/usa/daily/aapl.zip.
# Data for AAPL fetched from postgres, converted to LEAN format.
# Ticker MSFT already up-to-date
# data/equity/usa/daily/msft.csv has been successfully zipped into data/equity/usa/daily/msft.zip.
# Data for MSFT fetched from postgres, converted to LEAN format.
# Ticker NVDA already up-to-date
# data/equity/usa/daily/nvda.csv has been successfully zipped into data/equity/usa/daily/nvda.zip.
# Data for NVDA fetched from postgres, converted to LEAN format.
# Ticker AMZN already up-to-date
# data/equity/usa/daily/amzn.csv has been successfully zipped into data/equity/usa/daily/amzn.zip.
# Data for AMZN fetched from postgres, converted to LEAN format.
# Ticker TSLA already up-to-date
# data/equity/usa/daily/tsla.csv has been successfully zipped into data/equity/usa/daily/tsla.zip.
# Data for TSLA fetched from postgres, converted to LEAN format.
# Ticker HD already up-to-date
# data/equity/usa/daily/hd.csv has been successfully zipped into data/equity/usa/daily/hd.zip.
# Data for HD fetched from postgres, converted to LEAN format.
# Ticker UNH already up-to-date
# data/equity/usa/daily/unh.csv has been successfully zipped into data/equity/usa/daily/unh.zip.
# Data for UNH fetched from postgres, converted to LEAN format.
# Ticker JNJ already up-to-date
# data/equity/usa/daily/jnj.csv has been successfully zipped into data/equity/usa/daily/jnj.zip.
# Data for JNJ fetched from postgres, converted to LEAN format.
# Ticker LLY already up-to-date
# data/equity/usa/daily/lly.csv has been successfully zipped into data/equity/usa/daily/lly.zip.
# Data for LLY fetched from postgres, converted to LEAN format.
# Ticker JPM already up-to-date
# data/equity/usa/daily/jpm.csv has been successfully zipped into data/equity/usa/daily/jpm.zip.
# Data for JPM fetched from postgres, converted to LEAN format.
# Fetching data for BAC from 2019-01-01 to 2023-12-31
# c:\Users\MP\OneDrive\CASE\Projects\Coding\MachineLearning\XGBoost\databento_sql.py:23: BentoWarning: The streaming request contained one or more days which have reduced quality: 2020-06-22 (degraded), 2021-07-07 (degraded), 2021-10-26 (degraded)... See: https://databento.com/docs/api-reference-historical/metadata/metadata-get-dataset-condition
#   dataset = client.timeseries.get_range(
# Converting uint64 columns to int64: ['volume']
# Data for BAC uploaded successfully to databento_ohlcv.BAC.
# Ticker BAC data updated in PostgreSQL
# data/equity/usa/daily/bac.csv has been successfully zipped into data/equity/usa/daily/bac.zip.
# Data for BAC fetched from postgres, converted to LEAN format.
# Fetching data for WFC from 2019-01-01 to 2023-12-31
# c:\Users\MP\OneDrive\CASE\Projects\Coding\MachineLearning\XGBoost\databento_sql.py:23: BentoWarning: The streaming request contained one or more days which have reduced quality: 2020-06-22 (degraded), 2021-07-07 (degraded), 2021-10-26 (degraded)... See: https://databento.com/docs/api-reference-historical/metadata/metadata-get-dataset-condition
#   dataset = client.timeseries.get_range(
# Converting uint64 columns to int64: ['volume']
# Data for WFC uploaded successfully to databento_ohlcv.WFC.
# Ticker WFC data updated in PostgreSQL
# data/equity/usa/daily/wfc.csv has been successfully zipped into data/equity/usa/daily/wfc.zip.
# Data for WFC fetched from postgres, converted to LEAN format.
# Fetching data for XOM from 2019-01-01 to 2023-12-31
# c:\Users\MP\OneDrive\CASE\Projects\Coding\MachineLearning\XGBoost\databento_sql.py:23: BentoWarning: The streaming request contained one or more days which have reduced quality: 2020-06-22 (degraded), 2021-07-07 (degraded), 2021-10-26 (degraded)... See: https://databento.com/docs/api-reference-historical/metadata/metadata-get-dataset-condition
#   dataset = client.timeseries.get_range(
# Converting uint64 columns to int64: ['volume']
# Data for XOM uploaded successfully to databento_ohlcv.XOM.
# Ticker XOM data updated in PostgreSQL
# data/equity/usa/daily/xom.csv has been successfully zipped into data/equity/usa/daily/xom.zip.
# Data for XOM fetched from postgres, converted to LEAN format.
# Fetching data for CVX from 2019-01-01 to 2023-12-31
# c:\Users\MP\OneDrive\CASE\Projects\Coding\MachineLearning\XGBoost\databento_sql.py:23: BentoWarning: The streaming request contained one or more days which have reduced quality: 2020-06-22 (degraded), 2021-07-07 (degraded), 2021-10-26 (degraded)... See: https://databento.com/docs/api-reference-historical/metadata/metadata-get-dataset-condition
#   dataset = client.timeseries.get_range(
# Converting uint64 columns to int64: ['volume']
# Data for CVX uploaded successfully to databento_ohlcv.CVX.
# Ticker CVX data updated in PostgreSQL
# data/equity/usa/daily/cvx.csv has been successfully zipped into data/equity/usa/daily/cvx.zip.
# Data for CVX fetched from postgres, converted to LEAN format.
# Fetching data for COP from 2019-01-01 to 2023-12-31
# c:\Users\MP\OneDrive\CASE\Projects\Coding\MachineLearning\XGBoost\databento_sql.py:23: BentoWarning: The streaming request contained one or more days which have reduced quality: 2020-06-22 (degraded), 2021-07-07 (degraded), 2021-10-26 (degraded)... See: https://databento.com/docs/api-reference-historical/metadata/metadata-get-dataset-condition
#   dataset = client.timeseries.get_range(
# Converting uint64 columns to int64: ['volume']
# Data for COP uploaded successfully to databento_ohlcv.COP.
# Ticker COP data updated in PostgreSQL
# data/equity/usa/daily/cop.csv has been successfully zipped into data/equity/usa/daily/cop.zip.
# Data for COP fetched from postgres, converted to LEAN format.
# Fetching data for PG from 2019-01-01 to 2023-12-31
# c:\Users\MP\OneDrive\CASE\Projects\Coding\MachineLearning\XGBoost\databento_sql.py:23: BentoWarning: The streaming request contained one or more days which have reduced quality: 2020-06-22 (degraded), 2021-07-07 (degraded), 2021-10-26 (degraded)... See: https://databento.com/docs/api-reference-historical/metadata/metadata-get-dataset-condition
#   dataset = client.timeseries.get_range(
# Converting uint64 columns to int64: ['volume']
# Data for PG uploaded successfully to databento_ohlcv.PG.
# Ticker PG data updated in PostgreSQL
# data/equity/usa/daily/pg.csv has been successfully zipped into data/equity/usa/daily/pg.zip.
# Data for PG fetched from postgres, converted to LEAN format.
# Fetching data for KO from 2019-01-01 to 2023-12-31
# c:\Users\MP\OneDrive\CASE\Projects\Coding\MachineLearning\XGBoost\databento_sql.py:23: BentoWarning: The streaming request contained one or more days which have reduced quality: 2020-06-22 (degraded), 2021-07-07 (degraded), 2021-10-26 (degraded)... See: https://databento.com/docs/api-reference-historical/metadata/metadata-get-dataset-condition
#   dataset = client.timeseries.get_range(
# Converting uint64 columns to int64: ['volume']
# Data for KO uploaded successfully to databento_ohlcv.KO.
# Ticker KO data updated in PostgreSQL
# data/equity/usa/daily/ko.csv has been successfully zipped into data/equity/usa/daily/ko.zip.
# Data for KO fetched from postgres, converted to LEAN format.
# Fetching data for PEP from 2019-01-01 to 2023-12-31
# c:\Users\MP\OneDrive\CASE\Projects\Coding\MachineLearning\XGBoost\databento_sql.py:23: BentoWarning: The streaming request contained one or more days which have reduced quality: 2020-06-22 (degraded), 2021-07-07 (degraded), 2021-10-26 (degraded)... See: https://databento.com/docs/api-reference-historical/metadata/metadata-get-dataset-condition
#   dataset = client.timeseries.get_range(
# Converting uint64 columns to int64: ['volume']
# Data for PEP uploaded successfully to databento_ohlcv.PEP.
# Ticker PEP data updated in PostgreSQL
# data/equity/usa/daily/pep.csv has been successfully zipped into data/equity/usa/daily/pep.zip.
# Data for PEP fetched from postgres, converted to LEAN format.
# Fetching data for BA from 2019-01-01 to 2023-12-31
# c:\Users\MP\OneDrive\CASE\Projects\Coding\MachineLearning\XGBoost\databento_sql.py:23: BentoWarning: The streaming request contained one or more days which have reduced quality: 2020-06-22 (degraded), 2021-07-07 (degraded), 2021-10-26 (degraded)... See: https://databento.com/docs/api-reference-historical/metadata/metadata-get-dataset-condition
#   dataset = client.timeseries.get_range(
# Converting uint64 columns to int64: ['volume']
# Data for BA uploaded successfully to databento_ohlcv.BA.
# Ticker BA data updated in PostgreSQL
# data/equity/usa/daily/ba.csv has been successfully zipped into data/equity/usa/daily/ba.zip.
# Data for BA fetched from postgres, converted to LEAN format.
# Fetching data for CAT from 2019-01-01 to 2023-12-31
# c:\Users\MP\OneDrive\CASE\Projects\Coding\MachineLearning\XGBoost\databento_sql.py:23: BentoWarning: The streaming request contained one or more days which have reduced quality: 2020-06-22 (degraded), 2021-07-07 (degraded), 2021-10-26 (degraded)... See: https://databento.com/docs/api-reference-historical/metadata/metadata-get-dataset-condition
#   dataset = client.timeseries.get_range(
# Converting uint64 columns to int64: ['volume']
# Data for CAT uploaded successfully to databento_ohlcv.CAT.
# Ticker CAT data updated in PostgreSQL
# data/equity/usa/daily/cat.csv has been successfully zipped into data/equity/usa/daily/cat.zip.
# Data for CAT fetched from postgres, converted to LEAN format.
# Fetching data for UPS from 2019-01-01 to 2023-12-31
# c:\Users\MP\OneDrive\CASE\Projects\Coding\MachineLearning\XGBoost\databento_sql.py:23: BentoWarning: The streaming request contained one or more days which have reduced quality: 2020-06-22 (degraded), 2021-07-07 (degraded), 2021-10-26 (degraded)... See: https://databento.com/docs/api-reference-historical/metadata/metadata-get-dataset-condition
#   dataset = client.timeseries.get_range(
# Converting uint64 columns to int64: ['volume']
# Data for UPS uploaded successfully to databento_ohlcv.UPS.
# Ticker UPS data updated in PostgreSQL
# data/equity/usa/daily/ups.csv has been successfully zipped into data/equity/usa/daily/ups.zip.
# Data for UPS fetched from postgres, converted to LEAN format.
# Fetching data for LIN from 2019-01-01 to 2023-12-31
# c:\Users\MP\OneDrive\CASE\Projects\Coding\MachineLearning\XGBoost\databento_sql.py:23: BentoWarning: The streaming request contained one or more days which have reduced quality: 2020-06-22 (degraded), 2021-07-07 (degraded), 2021-10-26 (degraded)... See: https://databento.com/docs/api-reference-historical/metadata/metadata-get-dataset-condition
#   dataset = client.timeseries.get_range(
# Converting uint64 columns to int64: ['volume']
# Data for LIN uploaded successfully to databento_ohlcv.LIN.
# Ticker LIN data updated in PostgreSQL
# data/equity/usa/daily/lin.csv has been successfully zipped into data/equity/usa/daily/lin.zip.
# Data for LIN fetched from postgres, converted to LEAN format.
# Fetching data for APD from 2019-01-01 to 2023-12-31
# c:\Users\MP\OneDrive\CASE\Projects\Coding\MachineLearning\XGBoost\databento_sql.py:23: BentoWarning: The streaming request contained one or more days which have reduced quality: 2020-06-22 (degraded), 2021-07-07 (degraded), 2021-10-26 (degraded)... See: https://databento.com/docs/api-reference-historical/metadata/metadata-get-dataset-condition
#   dataset = client.timeseries.get_range(
# Converting uint64 columns to int64: ['volume']
# Data for APD uploaded successfully to databento_ohlcv.APD.
# Ticker APD data updated in PostgreSQL
# data/equity/usa/daily/apd.csv has been successfully zipped into data/equity/usa/daily/apd.zip.
# Data for APD fetched from postgres, converted to LEAN format.
# Fetching data for SHW from 2019-01-01 to 2023-12-31
# c:\Users\MP\OneDrive\CASE\Projects\Coding\MachineLearning\XGBoost\databento_sql.py:23: BentoWarning: The streaming request contained one or more days which have reduced quality: 2020-06-22 (degraded), 2021-07-07 (degraded), 2021-10-26 (degraded)... See: https://databento.com/docs/api-reference-historical/metadata/metadata-get-dataset-condition
#   dataset = client.timeseries.get_range(
# Converting uint64 columns to int64: ['volume']
# Data for SHW uploaded successfully to databento_ohlcv.SHW.
# Ticker SHW data updated in PostgreSQL
# data/equity/usa/daily/shw.csv has been successfully zipped into data/equity/usa/daily/shw.zip.
# Data for SHW fetched from postgres, converted to LEAN format.
# Fetching data for PLD from 2019-01-01 to 2023-12-31
# c:\Users\MP\OneDrive\CASE\Projects\Coding\MachineLearning\XGBoost\databento_sql.py:23: BentoWarning: The streaming request contained one or more days which have reduced quality: 2020-06-22 (degraded), 2021-07-07 (degraded), 2021-10-26 (degraded)... See: https://databento.com/docs/api-reference-historical/metadata/metadata-get-dataset-condition
#   dataset = client.timeseries.get_range(
# Converting uint64 columns to int64: ['volume']
# Data for PLD uploaded successfully to databento_ohlcv.PLD.
# Ticker PLD data updated in PostgreSQL
# data/equity/usa/daily/pld.csv has been successfully zipped into data/equity/usa/daily/pld.zip.
# Data for PLD fetched from postgres, converted to LEAN format.
# Fetching data for AMT from 2019-01-01 to 2023-12-31
# c:\Users\MP\OneDrive\CASE\Projects\Coding\MachineLearning\XGBoost\databento_sql.py:23: BentoWarning: The streaming request contained one or more days which have reduced quality: 2020-06-22 (degraded), 2021-07-07 (degraded), 2021-10-26 (degraded)... See: https://databento.com/docs/api-reference-historical/metadata/metadata-get-dataset-condition
#   dataset = client.timeseries.get_range(
# Converting uint64 columns to int64: ['volume']
# Data for AMT uploaded successfully to databento_ohlcv.AMT.
# Ticker AMT data updated in PostgreSQL
# data/equity/usa/daily/amt.csv has been successfully zipped into data/equity/usa/daily/amt.zip.
# Data for AMT fetched from postgres, converted to LEAN format.
# Fetching data for CCI from 2019-01-01 to 2023-12-31
# c:\Users\MP\OneDrive\CASE\Projects\Coding\MachineLearning\XGBoost\databento_sql.py:23: BentoWarning: The streaming request contained one or more days which have reduced quality: 2020-06-22 (degraded), 2021-07-07 (degraded), 2021-10-26 (degraded)... See: https://databento.com/docs/api-reference-historical/metadata/metadata-get-dataset-condition
#   dataset = client.timeseries.get_range(
# Converting uint64 columns to int64: ['volume']
# Data for CCI uploaded successfully to databento_ohlcv.CCI.
# Ticker CCI data updated in PostgreSQL
# data/equity/usa/daily/cci.csv has been successfully zipped into data/equity/usa/daily/cci.zip.
# Data for CCI fetched from postgres, converted to LEAN format.
# Fetching data for NEE from 2019-01-01 to 2023-12-31
# c:\Users\MP\OneDrive\CASE\Projects\Coding\MachineLearning\XGBoost\databento_sql.py:23: BentoWarning: The streaming request contained one or more days which have reduced quality: 2020-06-22 (degraded), 2021-07-07 (degraded), 2021-10-26 (degraded)... See: https://databento.com/docs/api-reference-historical/metadata/metadata-get-dataset-condition
#   dataset = client.timeseries.get_range(
# Converting uint64 columns to int64: ['volume']
# Data for NEE uploaded successfully to databento_ohlcv.NEE.
# Ticker NEE data updated in PostgreSQL
# data/equity/usa/daily/nee.csv has been successfully zipped into data/equity/usa/daily/nee.zip.
# Data for NEE fetched from postgres, converted to LEAN format.
# Fetching data for DUK from 2019-01-01 to 2023-12-31
# c:\Users\MP\OneDrive\CASE\Projects\Coding\MachineLearning\XGBoost\databento_sql.py:23: BentoWarning: The streaming request contained one or more days which have reduced quality: 2020-06-22 (degraded), 2021-07-07 (degraded), 2021-10-26 (degraded)... See: https://databento.com/docs/api-reference-historical/metadata/metadata-get-dataset-condition
#   dataset = client.timeseries.get_range(
# Converting uint64 columns to int64: ['volume']
# Data for DUK uploaded successfully to databento_ohlcv.DUK.
# Ticker DUK data updated in PostgreSQL
# data/equity/usa/daily/duk.csv has been successfully zipped into data/equity/usa/daily/duk.zip.
# Data for DUK fetched from postgres, converted to LEAN format.
# Fetching data for SO from 2019-01-01 to 2023-12-31
# c:\Users\MP\OneDrive\CASE\Projects\Coding\MachineLearning\XGBoost\databento_sql.py:23: BentoWarning: The streaming request contained one or more days which have reduced quality: 2020-06-22 (degraded), 2021-07-07 (degraded), 2021-10-26 (degraded)... See: https://databento.com/docs/api-reference-historical/metadata/metadata-get-dataset-condition
#   dataset = client.timeseries.get_range(
# Converting uint64 columns to int64: ['volume']
# Data for SO uploaded successfully to databento_ohlcv.SO.
# Ticker SO data updated in PostgreSQL
# data/equity/usa/daily/so.csv has been successfully zipped into data/equity/usa/daily/so.zip.
# Data for SO fetched from postgres, converted to LEAN format.

# %%
# Reused code from lean external data project
from datetime import datetime as dt
start_date = '2021-01-01'
end_date = '2023-12-31'
start_date = dt.strptime(start_date,'%Y-%m-%d')
end_date = dt.strptime(end_date,'%Y-%m-%d')
# Reused code from lean external data project
data = dbs.get_data_from_postgresql('SPY', start_date, end_date)
data
# Out:
#                      ts_event  rtype  publisher_id  instrument_id    open  \
# 0   2021-01-04 00:00:00+00:00     35             2           7999  375.74
# 1   2021-01-05 00:00:00+00:00     35             2           8005  369.12
# 2   2021-01-06 00:00:00+00:00     35             2           8008  368.62
# 3   2021-01-07 00:00:00+00:00     35             2           8017  375.75
# 4   2021-01-08 00:00:00+00:00     35             2           8033  380.17
# ..                        ...    ...           ...            ...     ...
# 748 2023-12-22 00:00:00+00:00     35             2          15144  472.10
# 749 2023-12-26 00:00:00+00:00     35             2          15144  474.41
# 750 2023-12-27 00:00:00+00:00     35             2          15144  475.69
# 751 2023-12-28 00:00:00+00:00     35             2          15144  477.06
# 752 2023-12-29 00:00:00+00:00     35             2          15144  477.38
#
#        high      low   close    volume symbol
# 0    376.72  364.810  368.70  15319113    SPY
# 1    372.49  366.840  370.95   8497108    SPY
# 2    376.98  368.160  374.50  15955607    SPY
# 3    379.89  374.250  379.48   9551523    SPY
# 4    381.96  377.110  381.60  10141260    SPY
# ..      ...      ...     ...       ...    ...
# 748  475.38  471.700  473.19   8888305    SPY
# 749  476.58  473.830  475.81   6626877    SPY
# 750  476.69  474.895  476.55   8328926    SPY
# 751  477.54  476.260  477.00   7473099    SPY
# 752  477.46  473.310  475.25  14702435    SPY
#
# [753 rows x 10 columns]

# %%
''' Setup Train Data, Prepare the data using DMatrix, optimized for XGBoost '''
import pandas as pd
import numpy as np
import databento_sql as dbs
#import ta_lib as ta

start_date = '2021-01-01'
end_date = '2023-06-30'
def prepdata(ticker, start_date, end_date):
    # Reused code from lean external data project
    #data = dbs.get_data_from_postgresql(ticker, start_date, end_date)
    

    df = pd.DataFrame(data)

    # Sort the data by date
    #df.iloc['ts_event'] = pd.to_datetime(df['ts_event'])
    df = df.sort_values(by='ts_event')

    # Feature creation (for example, lagged values of 'Close' price)
    df['close_lag1'] = df['close'].shift(1)
    df['close_lag2'] = df['close'].shift(2)

    # Drop the first few rows with NaN values after shifting
    df = df.dropna()

    # Features (X) and target (y)
    X = df[['close_lag1', 'close_lag2', 'volume']]  # Example features matrix
    y = df['close']  # Target is the current 'Close' price, the values we are trying to predict

    # Example of adding a moving average as a feature
    df['ma_50'] = df['close'].rolling(window=50).mean()
    X = df[['close_lag1', 'close_lag2', 'ma_50', 'volume']]

    dmat = xgb.DMatrix(X, label=y, missing=np.nan)
    return dmat
dtrain = prepdata('SPY', start_date, end_date)

# %%
''' Setting Test Data '''
start_date = '2023-07-01'
end_date = '2023-12-31'
dtest = prepdata('SPY', start_date, end_date)

# %%
''' 
Choose an appropriate objective function (e.g., reg:squarederror for regression, binary:logistic for classification).
'''
# Load data
#dtrain = xgb.DMatrix(X_train, label=y_train)
#dtest = xgb.DMatrix(X_test, label=y_test)

# Set parameters
params = {
    'objective': 'reg:squarederror',  # Regression task
    'eval_metric': 'rmse',            # Root mean square error
    'max_depth': 5,                   # Maximum depth of trees
    'learning_rate': 0.1,             # Step size shrinkage
    'n_estimators': 100               # Number of boosting rounds
}

# Train the model
model = xgb.train(params, dtrain, num_boost_round=100)

# Make predictions
y_pred = model.predict(dtest)
# Out:
# c:\Users\MP\anaconda3\envs\algo\lib\site-packages\xgboost\core.py:160: UserWarning: [08:45:23] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0b3782d1791676daf-1\xgboost\xgboost-ci-windows\src\learner.cc:742:
# Parameters: { "n_estimators" } are not used.
#
#   warnings.warn(smsg, UserWarning)

# %%
# Cross-validation
cv_results = xgb.cv(params, dtrain, num_boost_round=100, nfold=5, metrics={'rmse'}, early_stopping_rounds=10)
print(cv_results)
# Out:
# c:\Users\MP\anaconda3\envs\algo\lib\site-packages\xgboost\core.py:160: UserWarning: [08:46:03] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0b3782d1791676daf-1\xgboost\xgboost-ci-windows\src\learner.cc:742:
# Parameters: { "n_estimators" } are not used.
#
#   warnings.warn(smsg, UserWarning)
#     train-rmse-mean  train-rmse-std  test-rmse-mean  test-rmse-std
# 0         25.172491        0.375993       25.180903       1.528630
# 1         22.806113        0.339166       22.853502       1.415518
# 2         20.677623        0.306182       20.759432       1.321420
# 3         18.762332        0.277859       18.875267       1.235977
# 4         17.041347        0.251942       17.173846       1.158158
# 5         15.495390        0.229066       15.661521       1.082595
# 6         14.102927        0.208949       14.304118       1.023452
# 7         12.853029        0.188807       13.101881       0.952821
# 8         11.731594        0.171454       12.033314       0.915702
# 9         10.727331        0.155475       11.076206       0.879823
# 10         9.826968        0.143267       10.233144       0.838021
# 11         9.020743        0.133782        9.500924       0.813437
# 12         8.300171        0.125575        8.867345       0.766722
# 13         7.652391        0.117422        8.315197       0.754929
# 14         7.074276        0.112883        7.846950       0.733489
# 15         6.560575        0.106175        7.443572       0.712837
# 16         6.100793        0.101219        7.074295       0.694585
# 17         5.691873        0.098097        6.767782       0.658149
# 18         5.326650        0.092299        6.487979       0.637641
# 19         4.998108        0.085730        6.277325       0.615056
# 20         4.705923        0.079930        6.085281       0.587287
# 21         4.449135        0.076621        5.917836       0.577126
# 22         4.223718        0.075493        5.783759       0.549138
# 23         4.023631        0.073623        5.662907       0.526234
# 24         3.844900        0.072124        5.583164       0.519390
# 25         3.680225        0.069970        5.500608       0.489300
# 26         3.535131        0.067847        5.436941       0.478198
# 27         3.406461        0.065066        5.393327       0.482875
# 28         3.295993        0.064199        5.341471       0.467834
# 29         3.195148        0.066115        5.298976       0.462450
# 30         3.102290        0.065372        5.270968       0.459472
# 31         3.022354        0.069007        5.246125       0.451946
# 32         2.948759        0.066271        5.218207       0.443765
# 33         2.882239        0.063681        5.206999       0.445561
# 34         2.825887        0.067010        5.199977       0.443034
# 35         2.770068        0.067695        5.190977       0.436883
# 36         2.717542        0.063221        5.186941       0.438751
# 37         2.672935        0.064579        5.184711       0.435214
# 38         2.633904        0.064859        5.185863       0.444198
# 39         2.590523        0.060789        5.182678       0.441445
# 40         2.553045        0.065197        5.178883       0.441849
# 41         2.518685        0.064140        5.173488       0.443301
# 42         2.484482        0.067871        5.167415       0.444423
# 43         2.451394        0.069520        5.168375       0.445166
# 44         2.421547        0.071398        5.163193       0.444954
# 45         2.393140        0.072383        5.160374       0.449321
# 46         2.367674        0.074041        5.158413       0.445819
# 47         2.344609        0.073471        5.155237       0.448717

# %%
# Plot feature importance
xgb.plot_importance(model)
# Out:
# <Axes: title={'center': 'Feature importance'}, xlabel='F score', ylabel='Features'>

# %% [markdown]
# # 2. Adding Fundamental Key Metrics Data

# %%
import fmp_keymetrics
#ticker = ['AAPL','AMZN','GOOGL','MSFT']
start_date = '2019-01-01'
end_date = '2024-09-31'

fmp = fmp_keymetrics.funda_ETL()
keymetrics = fmp.download_funda_data(ticker_list, start=start_date, end=end_date)
keymetrics
# Out:
# Key Metrics for AAPL:
# [{'symbol': 'AAPL', 'date': '2024-06-29', 'calendarYear': '2024', 'period': 'Q3', 'revenuePerShare': 5.610916249926983, 'netIncomePerShare': 1.40297436059123, 'operatingCashFlowPerShare': 1.8876834249320082, 'freeCashFlowPerShare': 1.7469804293318714, 'cashPerShare': 4.042578257128804, 'bookValuePerShare': 4.363559009992529, 'tangibleBookValuePerShare': 4.363559009992529, 'shareholdersEquityPerShare': 4.363559009992529, 'interestDebtPerShare': 6.626581248849961, 'marketCap': 3219857673020, 'enterpriseValue': 3295596673020, 'peRatio': 37.53097809842409, 'priceToSalesRatio': 37.53754121757581, 'pocfratio': 111.57591215676763, 'pfcfRatio': 120.5623122409855, 'pbRatio': 48.26793897313666, 'ptbRatio': 48.26793897313666, 'evToSales': 38.420516840411764, 'enterpriseValueOverEBITDA': 116.85684252960783, 'evToOperatingCashFlow': 114.20045301198974, 'evToFreeCashFlow': 123.39823540719661, 'earningsYield': 0.006661163994830643, 'freeCashFlowYield': 0.00829446600195552, 'debtToEquity': 1.5186184565569347, 'debtToAssets': 0.3054895480260063, 'netDebtToEBITDA': 2.6855896744911707, 'currentRatio': 0.9529796997508053, 'interestCoverage': 0, 'incomeQuality': 1.3454867586721373, 'dividendYield': 0.0012096807982033455, 'payoutRatio': 0.18160201417381575, 'salesGeneralAndAdministrativeToRevenue': 0, 'researchAndDdevelopementToRevenue': 0.09333504319339683, 'intangiblesToTotalAssets': 0, 'capexToOperatingCashFlow': 0.07453738997851549, 'capexToRevenue': 0.025076652249437496, 'capexToDepreciation': 0.7547368421052632, 'stockBasedCompensationToRevenue': 0.0334471944693799, 'grahamNumber': 11.73644459658858, 'roic': 0.1269465036381191, 'returnOnTangibleAssets': 0.06467799717742422, 'grahamNetNet': -10.965904805625451, 'workingCapital': -6189000000, 'tangibleAssetValue': 66708000000, 'netCurrentAssetValue': -139469000000, 'investedCapital': 38313000000, 'averageReceivables': 42161000000, 'averagePayables': 46663500000, 'averageInventory
# Fundamental data for SO saved to table fundamental.SO
#    symbol period_ending calendarYear period  revenuePerShare  \
# 0    AAPL    2024-06-29         2024     Q3         5.610916
# 1    AAPL    2024-03-30         2024     Q2         5.890812
# 2    AAPL    2023-12-30         2024     Q1         7.709660
# 3    AAPL    2023-09-30         2023     Q4         5.737259
# 4    AAPL    2023-07-01         2023     Q3         5.210792
# ..    ...           ...          ...    ...              ...
# 18     SO    2019-12-31         2019     Q4         4.671097
# 19     SO    2019-09-30         2019     Q3         5.720420
# 20     SO    2019-06-30         2019     Q2         4.877388
# 21     SO    2019-03-31         2019     Q1         5.213873
# 22     SO    2018-12-31         2018     Q4         5.162567
#
#     netIncomePerShare  operatingCashFlowPerShare  freeCashFlowPerShare  \
# 0            1.402974                   1.887683              1.746980
# 1            1.534222                   1.472817              1.343255
# 2            2.186752                   2.572251              2.418025
# 3            1.471592                   1.384537              1.245879
# 4            1.266498                   1.680510              1.547178
# ..                ...                        ...                   ...
# 18           0.423003                   0.855512             -1.176805
# 19           1.259542                   2.259542              0.415076
# 20           0.862967                   1.692448             -0.035399
# 21           2.011561                   0.716763             -0.899807
# 22           0.272783                   1.316518             -0.819317
#
#     cashPerShare  bookValuePerShare  ...  averagePayables  averageInventory  \
# 0       4.042578           4.363559  ...      46663500000      6.198500e+09
# 1       4.358732           4.815961  ...      51949500000      6.371500e+09
# 2       4.713160           4.777636  ...      60378500000      6.421000e+09
# 3       3.945977           3.983862  ...      54655000000      6.841000e+09
# 4       3.980350           3.839692  ...      44822000000      7.416500e+09
# ..           ...                ...  ...              ...               ...
# 18      1.877374          30.465742  ...       2411500000      2.356000e+09
# 19      2.796756          30.612595  ...       2318500000      2.233500e+09
# 20      1.323152          30.062236  ...       2470000000      2.118000e+09
# 21      1.311175          29.843931  ...       3002500000      2.243500e+09
# 22      1.350374          28.371388  ...       3101500000      2.344000e+09
#
#     daysSalesOutstanding  daysPayablesOutstanding  daysOfInventoryOnHand  \
# 0              45.297457                92.879672              12.036053
# 1              40.808568                84.933996              11.568830
# 2              37.710056                80.858158               9.054234
# 3              61.327069               114.833405              11.611542
# 4              43.115762                92.607747              14.577604
# ..                   ...                      ...                    ...
# 18             62.435897                72.573321              67.776727
# 19             50.817348                72.550694              74.407684
# 20             59.546881                78.858093              71.274945
# 21             61.347007                73.727679              60.066964
# 22             68.448567                85.662050              59.684211
#
#     receivablesTurnover  payablesTurnover  inventoryTurnover       roe  \
# 0              1.986866          0.968996           7.477534  0.321521
# 1              2.205419          1.059646           7.779525  0.318570
# 2              2.386631          1.113060           9.940101  0.457706
# 3              1.467541          0.783744           7.750908  0.369388
# 4              2.087404          0.971841           6.173854  0.329844
# ..                  ...               ...                ...       ...
# 18             1.441478          1.240125           1.327889  0.016009
# 19             1.771049          1.240512           1.209552  0.047475
# 20             1.511414          1.141291           1.262716  0.033175
# 21             1.467064          1.220708           1.498328  0.078120
# 22             1.314856          1.050640           1.507937  0.011274
#
#     capexPerShare
# 0        0.140703
# 1        0.129561
# 2        0.154225
# 3        0.138659
# 4        0.133332
# ..            ...
# 18       2.032317
# 19       1.844466
# 20       1.727847
# 21       1.616570
# 22       2.135834
#
# [690 rows x 61 columns]

# %%
# Download the Data from Postgres
import databento_sql as dbs
tickers = ['AAPL','AMZN','GOOGL','MSFT']
for ticker in tickers:
    dbs.download_and_append_data(ticker, '2019-01-01', '2023-12-31', frequency='daily')
# Out:
# Fetching data for AAPL from 2019-01-01 to 2023-12-31
# c:\Users\MP\OneDrive\CASE\Projects\Coding\MachineLearning\XGBoost\databento_sql.py:23: BentoWarning: The streaming request contained one or more days which have reduced quality: 2020-06-22 (degraded), 2021-07-07 (degraded), 2021-10-26 (degraded)... See: https://databento.com/docs/api-reference-historical/metadata/metadata-get-dataset-condition
#   dataset = client.timeseries.get_range(
# Converting uint64 columns to int64: ['volume']
# Data for AAPL uploaded successfully to databento_ohlcv.AAPL.
# Ticker AAPL data updated in PostgreSQL
# Error retrieving data for AAPL from PostgreSQL: strptime() argument 1 must be str, not Timestamp
# No data available for AAPL to convert.
# Fetching data for AMZN from 2019-01-01 to 2023-12-31
# c:\Users\MP\OneDrive\CASE\Projects\Coding\MachineLearning\XGBoost\databento_sql.py:23: BentoWarning: The streaming request contained one or more days which have reduced quality: 2020-06-22 (degraded), 2021-07-07 (degraded), 2021-10-26 (degraded)... See: https://databento.com/docs/api-reference-historical/metadata/metadata-get-dataset-condition
#   dataset = client.timeseries.get_range(
# Converting uint64 columns to int64: ['volume']
# Data for AMZN uploaded successfully to databento_ohlcv.AMZN.
# Ticker AMZN data updated in PostgreSQL
# Error retrieving data for AMZN from PostgreSQL: strptime() argument 1 must be str, not Timestamp
# No data available for AMZN to convert.
# Fetching data for GOOGL from 2019-01-01 to 2023-12-31
# c:\Users\MP\OneDrive\CASE\Projects\Coding\MachineLearning\XGBoost\databento_sql.py:23: BentoWarning: The streaming request contained one or more days which have reduced quality: 2020-06-22 (degraded), 2021-07-07 (degraded), 2021-10-26 (degraded)... See: https://databento.com/docs/api-reference-historical/metadata/metadata-get-dataset-condition
#   dataset = client.timeseries.get_range(
# Converting uint64 columns to int64: ['volume']
# Data for GOOGL uploaded successfully to databento_ohlcv.GOOGL.
# Ticker GOOGL data updated in PostgreSQL
# Error retrieving data for GOOGL from PostgreSQL: strptime() argument 1 must be str, not Timestamp
# No data available for GOOGL to convert.
# Fetching data for MSFT from 2019-01-01 to 2023-12-31
# c:\Users\MP\OneDrive\CASE\Projects\Coding\MachineLearning\XGBoost\databento_sql.py:23: BentoWarning: The streaming request contained one or more days which have reduced quality: 2020-06-22 (degraded), 2021-07-07 (degraded), 2021-10-26 (degraded)... See: https://databento.com/docs/api-reference-historical/metadata/metadata-get-dataset-condition
#   dataset = client.timeseries.get_range(
# Converting uint64 columns to int64: ['volume']
# Data for MSFT uploaded successfully to databento_ohlcv.MSFT.
# Ticker MSFT data updated in PostgreSQL
# Error retrieving data for MSFT from PostgreSQL: strptime() argument 1 must be str, not Timestamp
# No data available for MSFT to convert.
# PriceVol or Fundamental table for M is missing. Run the datapipe first!

# %%
import pandas as pd
from datetime import datetime
#tickers = ['AAPL','AMZN','GOOGL','MSFT']
tickers = ['AAPL']
engine = 'postgresql://eqty:1234@192.168.17.4:5432/FinancialData'
for ticker in tickers:
    pricevol = pd.read_sql_table(ticker, engine, schema='databento_ohlcv')

pricevol['date'] = pd.to_datetime(pricevol['ts_event'],'%Y-%m-%d')
pricevol['date'] = pricevol['date'].dt.date
print(pricevol.head())
# Out:
#                    ts_event  rtype  publisher_id  instrument_id    open  \
# 0 2018-12-31 00:00:00+00:00     35             2             14  157.55
# 1 2019-01-02 00:00:00+00:00     35             2             14  153.88
# 2 2019-01-03 00:00:00+00:00     35             2             14  145.99
# 3 2019-01-04 00:00:00+00:00     35             2             14  144.00
# 4 2019-01-07 00:00:00+00:00     35             2             14  148.80
#
#      high     low   close    volume symbol        date
# 0  159.36  156.51  157.91   9129977   AAPL  2018-12-31
# 1  158.84  144.51  146.09  10526569   AAPL  2019-01-02
# 2  146.66  142.00  142.58  24831049   AAPL  2019-01-03
# 3  148.54  143.61  148.11  16654238   AAPL  2019-01-04
# 4  148.90  145.90  147.70  14586570   AAPL  2019-01-07

# %%
import combiner
comb = combiner.combine_pvol_funda()
#tickers = ['AAPL','AMZN','GOOGL','MSFT']
merged = comb.merge_pvol_funda(ticker_list)
# Out:
# PriceVol data loaded for AAPL
# Fundamental data loaded for AAPL
# Price-volume fundamental data for AAPL saved to table comb_pvol_funda.AAPL
# PriceVol data loaded for MSFT
# Fundamental data loaded for MSFT
# Price-volume fundamental data for MSFT saved to table comb_pvol_funda.MSFT
# PriceVol data loaded for NVDA
# Fundamental data loaded for NVDA
# Price-volume fundamental data for NVDA saved to table comb_pvol_funda.NVDA
# PriceVol data loaded for AMZN
# Fundamental data loaded for AMZN
# Price-volume fundamental data for AMZN saved to table comb_pvol_funda.AMZN
# PriceVol data loaded for TSLA
# Fundamental data loaded for TSLA
# Price-volume fundamental data for TSLA saved to table comb_pvol_funda.TSLA
# PriceVol data loaded for HD
# Fundamental data loaded for HD
# Price-volume fundamental data for HD saved to table comb_pvol_funda.HD
# PriceVol data loaded for UNH
# Fundamental data loaded for UNH
# Price-volume fundamental data for UNH saved to table comb_pvol_funda.UNH
# PriceVol data loaded for JNJ
# Fundamental data loaded for JNJ
# Price-volume fundamental data for JNJ saved to table comb_pvol_funda.JNJ
# PriceVol data loaded for LLY
# Fundamental data loaded for LLY
# Price-volume fundamental data for LLY saved to table comb_pvol_funda.LLY
# PriceVol data loaded for JPM
# Fundamental data loaded for JPM
# Price-volume fundamental data for JPM saved to table comb_pvol_funda.JPM
# PriceVol data loaded for BAC
# Fundamental data loaded for BAC
# Price-volume fundamental data for BAC saved to table comb_pvol_funda.BAC
# PriceVol data loaded for WFC
# Fundamental data loaded for WFC
# Price-volume fundamental data for WFC saved to table comb_pvol_funda.WFC
# PriceVol data loaded for XOM
# Fundamental data loaded for XOM
# Price-volume fundamental data for XOM saved to table comb_pvol_funda.XOM
# PriceVol data loaded for CVX
# Fundamental data loaded for CVX
# Price-volume fundamental data for CVX saved to table comb_pvol_funda.CVX
# PriceVol data loaded for COP
# Fundamental data loaded for COP
# Price-volume fundamental data for COP saved to table comb_pvol_funda.COP
# PriceVol data loaded for PG
# Fundamental data loaded for PG
# Price-volume fundamental data for PG saved to table comb_pvol_funda.PG
# PriceVol data loaded for KO
# Fundamental data loaded for KO
# Price-volume fundamental data for KO saved to table comb_pvol_funda.KO
# PriceVol data loaded for PEP
# Fundamental data loaded for PEP
# Price-volume fundamental data for PEP saved to table comb_pvol_funda.PEP
# PriceVol data loaded for BA
# Fundamental data loaded for BA
# Price-volume fundamental data for BA saved to table comb_pvol_funda.BA
# PriceVol data loaded for CAT
# Fundamental data loaded for CAT
# Price-volume fundamental data for CAT saved to table comb_pvol_funda.CAT
# PriceVol data loaded for UPS
# Fundamental data loaded for UPS
# Price-volume fundamental data for UPS saved to table comb_pvol_funda.UPS
# PriceVol data loaded for LIN
# Fundamental data loaded for LIN
# Price-volume fundamental data for LIN saved to table comb_pvol_funda.LIN
# PriceVol data loaded for APD
# Fundamental data loaded for APD
# Price-volume fundamental data for APD saved to table comb_pvol_funda.APD
# PriceVol data loaded for SHW
# Fundamental data loaded for SHW
# Price-volume fundamental data for SHW saved to table comb_pvol_funda.SHW
# PriceVol data loaded for PLD
# Fundamental data loaded for PLD
# Price-volume fundamental data for PLD saved to table comb_pvol_funda.PLD
# PriceVol data loaded for AMT
# Fundamental data loaded for AMT
# Price-volume fundamental data for AMT saved to table comb_pvol_funda.AMT
# PriceVol data loaded for CCI
# Fundamental data loaded for CCI
# Price-volume fundamental data for CCI saved to table comb_pvol_funda.CCI
# PriceVol data loaded for NEE
# Fundamental data loaded for NEE
# Price-volume fundamental data for NEE saved to table comb_pvol_funda.NEE
# PriceVol data loaded for DUK
# Fundamental data loaded for DUK
# Price-volume fundamental data for DUK saved to table comb_pvol_funda.DUK
# PriceVol data loaded for SO
# Fundamental data loaded for SO
# Price-volume fundamental data for SO saved to table comb_pvol_funda.SO

# %% [markdown]
# # 3. Using these new pvol fundamentals,
# We can now add them to the XGBoost model to see if it improves the model's performance.

# %%
import combiner
comb = combiner.combine_pvol_funda()
tickers = ['AAPL','AMZN','GOOGL','MSFT']
#f'{tickers}' = comb.download_combined_data_sql(tickers, '2019-01-01', '2023-12-31')
for ticker in tickers:
    globals()[ticker] = comb.get_comb_data_from_postgresql(ticker, '2019-01-01', '2023-12-31')

# %%
AAPL.head()
# Out:
#      open     high     low   close    volume symbol                      date  \
# 0  153.88  158.840  144.51  146.09  10526569   AAPL 2019-01-02 00:00:00+00:00
# 1  145.99  146.660  142.00  142.58  24831049   AAPL 2019-01-03 00:00:00+00:00
# 2  144.00  148.540  143.61  148.11  16654238   AAPL 2019-01-04 00:00:00+00:00
# 3  148.80  148.900  145.90  147.70  14586570   AAPL 2019-01-07 00:00:00+00:00
# 4  148.65  151.815  148.00  151.00  10027250   AAPL 2019-01-08 00:00:00+00:00
#
#    year quarter Quarter_Label  ... averagePayables averageInventory  \
# 0  2019      Q1        Q12019  ...             NaN              NaN
# 1  2019      Q1        Q12019  ...             NaN              NaN
# 2  2019      Q1        Q12019  ...             NaN              NaN
# 3  2019      Q1        Q12019  ...             NaN              NaN
# 4  2019      Q1        Q12019  ...             NaN              NaN
#
#    daysSalesOutstanding  daysPayablesOutstanding  daysOfInventoryOnHand  \
# 0                   NaN                      NaN                    NaN
# 1                   NaN                      NaN                    NaN
# 2                   NaN                      NaN                    NaN
# 3                   NaN                      NaN                    NaN
# 4                   NaN                      NaN                    NaN
#
#    receivablesTurnover  payablesTurnover  inventoryTurnover  roe  \
# 0                  NaN               NaN                NaN  NaN
# 1                  NaN               NaN                NaN  NaN
# 2                  NaN               NaN                NaN  NaN
# 3                  NaN               NaN                NaN  NaN
# 4                  NaN               NaN                NaN  NaN
#
#    capexPerShare
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
#
# [5 rows x 69 columns]

# %%
import pandas as pd
import numpy as np
import xgboost as xgb
import combiner
comb = combiner.combine_pvol_funda()

def prepdata(ticker, start_date, end_date):
    # Retrieve data for the ticker and date range
    data = comb.get_comb_data_from_postgresql(ticker, start_date, end_date)

    df = pd.DataFrame(data)

    # Sort the data by date
    df['date'] = pd.to_datetime(df['date'])
    df = df.sort_values(by='date')

    # Feature creation (for example, lagged values of 'Close' price)
    df['close_lag1'] = df['close'].shift(1)
    df['close_lag2'] = df['close'].shift(2)
    
    # Add moving averages or other technical indicators
    df['ma_50'] = df['close'].rolling(window=50).mean()

    # Define the fundamental columns (K to BQ)
    fundamental_columns = [
        'revenuePerShare', 'netIncomePerShare', 'operatingCashFlowPerShare', 'freeCashFlowPerShare', 
        'cashPerShare', 'bookValuePerShare', 'tangibleBookValuePerShare', 'shareholdersEquityPerShare', 
        'interestDebtPerShare', 'marketCap', 'enterpriseValue', 'peRatio', 'priceToSalesRatio', 
        'pocfratio', 'pfcfRatio', 'pbRatio', 'ptbRatio', 'evToSales', 'enterpriseValueOverEBITDA', 
        'evToOperatingCashFlow', 'evToFreeCashFlow', 'earningsYield', 'freeCashFlowYield', 
        'debtToEquity', 'debtToAssets', 'netDebtToEBITDA', 'currentRatio', 'interestCoverage', 
        'incomeQuality', 'dividendYield', 'payoutRatio', 'salesGeneralAndAdministrativeToRevenue', 
        'researchAndDdevelopementToRevenue', 'intangiblesToTotalAssets', 'capexToOperatingCashFlow', 
        'capexToRevenue', 'capexToDepreciation', 'stockBasedCompensationToRevenue', 'grahamNumber', 
        'roic', 'returnOnTangibleAssets', 'grahamNetNet', 'workingCapital', 'tangibleAssetValue', 
        'netCurrentAssetValue', 'investedCapital', 'averageReceivables', 'averagePayables', 
        'averageInventory', 'daysSalesOutstanding', 'daysPayablesOutstanding', 
        'daysOfInventoryOnHand', 'receivablesTurnover', 'payablesTurnover', 'inventoryTurnover', 
        'roe', 'capexPerShare'
    ]

    # Drop rows with NaN values in the technical columns
    df = df.dropna(subset=['close_lag1', 'close_lag2', 'ma_50'])

    # Forward fill any missing fundamental data (or fill with zeros if necessary)
    df[fundamental_columns] = df[fundamental_columns].fillna(method='ffill').fillna(0)

    # Define the features (X) and target (y)
    X = df[['close_lag1', 'close_lag2', 'ma_50', 'volume'] + fundamental_columns]  # Adding fundamental columns to the feature matrix
    y = df['close']  # Target is the current 'Close' price

    # Convert to DMatrix
    dmat = xgb.DMatrix(X, label=y, missing=np.nan)
    
    return dmat

# Example of how to use the updated function
ticker_list = ['AAPL']
for ticker in ticker_list:
    start_date = '2019-01-01'
    end_date = '2022-12-31'
    dtrain = prepdata(ticker, start_date, end_date)

    ''' Setting Test Data '''
    start_date = '2023-01-01'
    end_date = '2023-12-31'
    dtest = prepdata(ticker, start_date, end_date)
# Out:
# C:\Users\MP\AppData\Local\Temp\ipykernel_22332\2279897975.py:46: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[fundamental_columns] = df[fundamental_columns].fillna(method='ffill').fillna(0)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 77
#      74 end_date = '2022-12-31'
#      76 # Prepare the training data using log returns
# ---> 77 dtrain = prepdata(ticker, start_date, end_date, use_log_return=True)
#      79 ''' Setting Test Data '''
#      80 start_date = '2023-01-01'
#
# Cell In[8], line 63, in prepdata(ticker, start_date, end_date, use_log_return)
#      60 X = df[['close_lag1', 'close_lag2', 'ma_50', 'volume'] + fundamental_columns]
#      62 # Ensure that both X and y have the same index
# ---> 63 X = X.loc[y.index]
#      65 # Convert to DMatrix
#      66 dmat = xgb.DMatrix(X, label=y, missing=np.nan)
#
# File c:\Users\MP\anaconda3\envs\algo\lib\site-packages\pandas\core\indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File c:\Users\MP\anaconda3\envs\algo\lib\site-packages\pandas\core\indexing.py:1420, in _LocIndexer._getitem_axis(self, key, axis)
#    1417     if hasattr(key, "ndim") and key.ndim > 1:
#    1418         raise ValueError("Cannot index with multidimensional key")
# -> 1420     return self._getitem_iterable(key, axis=axis)
#    1422 # nested tuple slicing
#    1423 if is_nested_tuple(key, labels):
#
# File c:\Users\MP\anaconda3\envs\algo\lib\site-packages\pandas\core\indexing.py:1360, in _LocIndexer._getitem_iterable(self, key, axis)
#    1357 self._validate_key(key, axis)
#    1359 # A collection of keys
# -> 1360 keyarr, indexer = self._get_listlike_indexer(key, axis)
#    1361 return self.obj._reindex_with_indexers(
#    1362     {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#    1363 )
#
# File c:\Users\MP\anaconda3\envs\algo\lib\site-packages\pandas\core\indexing.py:1558, in _LocIndexer._get_listlike_indexer(self, key, axis)
#    1555 ax = self.obj._get_axis(axis)
#    1556 axis_name = self.obj._get_axis_name(axis)
# -> 1558 keyarr, indexer = ax._get_indexer_strict(key, axis_name)
#    1560 return keyarr, indexer
#
# File c:\Users\MP\anaconda3\envs\algo\lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File c:\Users\MP\anaconda3\envs\algo\lib\site-packages\pandas\core\indexes\base.py:6252, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6249     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6252 raise KeyError(f"{not_found} not in index")
#
# KeyError: '[49] not in index'

# %%
import pandas as pd
import numpy as np
import xgboost as xgb
import combiner

# Initialize combiner instance
comb = combiner.combine_pvol_funda()

def prepdata(ticker, start_date, end_date):
    # Retrieve data for the ticker and date range
    data = comb.get_comb_data_from_postgresql(ticker, start_date, end_date)

    # Create a DataFrame
    df = pd.DataFrame(data)

    # Sort the data by date
    df['date'] = pd.to_datetime(df['date'])
    df = df.sort_values(by='date')

    # Calculate log returns as the target variable
    df['log_return'] = np.log(df['close'] / df['close'].shift(1))

    # Drop rows with NaN values in log returns (first row will always be NaN)
    df = df.dropna(subset=['log_return'])

    # Define the fundamental columns to use as features (K to BQ)
    fundamental_columns = [
        'revenuePerShare', 'netIncomePerShare', 'operatingCashFlowPerShare', 'freeCashFlowPerShare', 
        'cashPerShare', 'bookValuePerShare', 'tangibleBookValuePerShare', 'shareholdersEquityPerShare', 
        'interestDebtPerShare', 'marketCap', 'enterpriseValue', 'peRatio', 'priceToSalesRatio', 
        'pocfratio', 'pfcfRatio', 'pbRatio', 'ptbRatio', 'evToSales', 'enterpriseValueOverEBITDA', 
        'evToOperatingCashFlow', 'evToFreeCashFlow', 'earningsYield', 'freeCashFlowYield', 
        'debtToEquity', 'debtToAssets', 'netDebtToEBITDA', 'currentRatio', 'interestCoverage', 
        'incomeQuality', 'dividendYield', 'payoutRatio', 'salesGeneralAndAdministrativeToRevenue', 
        'researchAndDdevelopementToRevenue', 'intangiblesToTotalAssets', 'capexToOperatingCashFlow', 
        'capexToRevenue', 'capexToDepreciation', 'stockBasedCompensationToRevenue', 'grahamNumber', 
        'roic', 'returnOnTangibleAssets', 'grahamNetNet', 'workingCapital', 'tangibleAssetValue', 
        'netCurrentAssetValue', 'investedCapital', 'averageReceivables', 'averagePayables', 
        'averageInventory', 'daysSalesOutstanding', 'daysPayablesOutstanding', 
        'daysOfInventoryOnHand', 'receivablesTurnover', 'payablesTurnover', 'inventoryTurnover', 
        'roe', 'capexPerShare'
    ]

    # Fill missing values in the fundamental columns using forward fill, followed by zeros if necessary
    df[fundamental_columns] = df[fundamental_columns].fillna(method='ffill').fillna(0)

    # Define features (X) and target (y)
    X = df[fundamental_columns]
    y = df['log_return']
    # Convert features and target into an XGBoost DMatrix
    dmat = xgb.DMatrix(X, label=y, missing=np.nan)

    return dmat, X

# Example of how to use the updated function
ticker_list = ['AAPL']
for ticker in ticker_list:
    start_date = '2019-01-01'
    end_date = '2022-12-31'

    # Prepare the training data using log returns
    dtrain = prepdata(ticker, start_date, end_date)

    ''' Setting Test Data '''
    start_date = '2023-01-01'
    end_date = '2023-12-31'

    # Prepare the test data
    dtest = prepdata(ticker, start_date, end_date)
# Out:
# C:\Users\MP\AppData\Local\Temp\ipykernel_22332\855412294.py:45: FutureWarning:
#
# DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#
# C:\Users\MP\AppData\Local\Temp\ipykernel_22332\855412294.py:45: FutureWarning:
#
# DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.

# %%
''' 
Choose an appropriate objective function (e.g., reg:squarederror for regression, binary:logistic for classification).
'''
# Load data
#dtrain = xgb.DMatrix(X_train, label=y_train)
#dtest = xgb.DMatrix(X_test, label=y_test)

# Set parameters
params = {
    'objective': 'reg:squarederror',  # Regression task
    'eval_metric': 'rmse',            # Root mean square error
    'max_depth': 5,                   # Maximum depth of trees
    'learning_rate': 0.1,             # Step size shrinkage
    'n_estimators': 100               # Number of boosting rounds
}

# Train the model
model = xgb.train(params, dtrain, num_boost_round=100)

# Make predictions
y_pred = model.predict(dtest)
# Out:
# c:\Users\MP\anaconda3\envs\algo\lib\site-packages\xgboost\core.py:160: UserWarning:
#
# [18:00:21] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0b3782d1791676daf-1\xgboost\xgboost-ci-windows\src\learner.cc:742:
# Parameters: { "n_estimators" } are not used.

# %%
# Cross-validation
cv_results = xgb.cv(params, dtrain, num_boost_round=100, nfold=5, metrics={'rmse'}, early_stopping_rounds=10)
print(cv_results)
# Out:
# c:\Users\MP\anaconda3\envs\algo\lib\site-packages\xgboost\core.py:160: UserWarning:
#
# [18:00:24] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0b3782d1791676daf-1\xgboost\xgboost-ci-windows\src\learner.cc:742:
# Parameters: { "n_estimators" } are not used.
#    train-rmse-mean  train-rmse-std  test-rmse-mean  test-rmse-std
# 0         0.046302        0.012141        0.037259       0.030209

# %%
# Plot feature importance
xgb.plot_importance(model)
# Out:
# <Axes: title={'center': 'Feature importance'}, xlabel='F score', ylabel='Features'>

# %%
# Visualize Log Returns distribution
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Example: calculate log returns
def calculate_log_returns(df):
    df['log_return'] = np.log(df['close'] / df['close'].shift(1))
    df = df.dropna(subset=['log_return'])
    return df

# Retrieve data for a specific ticker (as an example, assuming you already have this)
ticker = 'AAPL'
start_date = '2019-01-01'
end_date = '2022-12-31'

# Fetch data using the combiner (assuming combiner is already initialized)
data = comb.get_comb_data_from_postgresql(ticker, start_date, end_date)
df = pd.DataFrame(data)
df['date'] = pd.to_datetime(df['date'])
df = df.sort_values(by='date')

# Calculate log returns
df = calculate_log_returns(df)

# Plot the distribution of log returns
plt.figure(figsize=(10, 6))
sns.histplot(df['log_return'], bins=50, kde=True, color='green')
plt.title(f'Log Returns Distribution for {ticker}')
plt.xlabel('Log Return')
plt.ylabel('Frequency')
plt.show()

# %%
### Version that passes actual values and predictions into the model to evalue usign m

import pandas as pd
import numpy as np
import xgboost as xgb
import combiner

# Initialize combiner instance
comb = combiner.combine_pvol_funda()

def prepdata(ticker, start_date, end_date):
    # Retrieve data for the ticker and date range
    data = comb.get_comb_data_from_postgresql(ticker, start_date, end_date)

    # Create a DataFrame
    df = pd.DataFrame(data)

    # Sort the data by date
    df['date'] = pd.to_datetime(df['date'])
    df = df.sort_values(by='date')

    # Calculate log returns as the target variable
    df['log_return'] = np.log(df['close'] / df['close'].shift(1))

    # Drop rows with NaN values in log returns (first row will always be NaN)
    df = df.dropna(subset=['log_return'])

    # Define the fundamental columns to use as features (K to BQ)
    fundamental_columns = [
        'revenuePerShare', 'netIncomePerShare', 'operatingCashFlowPerShare', 'freeCashFlowPerShare', 
        'cashPerShare', 'bookValuePerShare', 'tangibleBookValuePerShare', 'shareholdersEquityPerShare', 
        'interestDebtPerShare', 'marketCap', 'enterpriseValue', 'peRatio', 'priceToSalesRatio', 
        'pocfratio', 'pfcfRatio', 'pbRatio', 'ptbRatio', 'evToSales', 'enterpriseValueOverEBITDA', 
        'evToOperatingCashFlow', 'evToFreeCashFlow', 'earningsYield', 'freeCashFlowYield', 
        'debtToEquity', 'debtToAssets', 'netDebtToEBITDA', 'currentRatio', 'interestCoverage', 
        'incomeQuality', 'dividendYield', 'payoutRatio', 'salesGeneralAndAdministrativeToRevenue', 
        'researchAndDdevelopementToRevenue', 'intangiblesToTotalAssets', 'capexToOperatingCashFlow', 
        'capexToRevenue', 'capexToDepreciation', 'stockBasedCompensationToRevenue', 'grahamNumber', 
        'roic', 'returnOnTangibleAssets', 'grahamNetNet', 'workingCapital', 'tangibleAssetValue', 
        'netCurrentAssetValue', 'investedCapital', 'averageReceivables', 'averagePayables', 
        'averageInventory', 'daysSalesOutstanding', 'daysPayablesOutstanding', 
        'daysOfInventoryOnHand', 'receivablesTurnover', 'payablesTurnover', 'inventoryTurnover', 
        'roe', 'capexPerShare'
    ]

    # Fill missing values in the fundamental columns using forward fill, followed by zeros if necessary
    df[fundamental_columns] = df[fundamental_columns].fillna(method='ffill').fillna(0)

    # Define features (X) and target (y)
    X = df[fundamental_columns]
    y = df['log_return']

    # Convert features into an XGBoost DMatrix
    dmat = xgb.DMatrix(X, label=y, missing=np.nan)

    return dmat, y

# Example of how to use the updated function
ticker_list = ['AAPL']
for ticker in ticker_list:
    start_date = '2019-01-01'
    end_date = '2022-12-31'

    # Prepare the training data using log returns
    dtrain, y_train = prepdata(ticker, start_date, end_date)

    ''' Setting Test Data '''
    start_date = '2023-01-01'
    end_date = '2023-12-31'

    # Prepare the test data
    dtest, y_test = prepdata(ticker, start_date, end_date)
# Out:
# C:\Users\MP\AppData\Local\Temp\ipykernel_22332\2798626362.py:47: FutureWarning:
#
# DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#
# C:\Users\MP\AppData\Local\Temp\ipykernel_22332\2798626362.py:47: FutureWarning:
#
# DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

def evaluate_model(model, dtest, y_test):
    # Predict using the trained model
    y_pred = model.predict(dtest)

    # Calculate evaluation metrics
    mae = mean_absolute_error(y_test, y_pred)
    mse = mean_squared_error(y_test, y_pred)
    rmse = np.sqrt(mse)
    r2 = r2_score(y_test, y_pred)

    # Print results
    print(f"Mean Absolute Error (MAE): {mae}")
    print(f"Mean Squared Error (MSE): {mse}")
    print(f"Root Mean Squared Error (RMSE): {rmse}")
    print(f"R-squared (R²): {r2}")
    
    return mae, mse, rmse, r2

# Assuming your trained XGBoost model is `xgb_model`
evaluate_model(model, dtest, y_test)
# Out:
# Mean Absolute Error (MAE): 0.010983773626311345
# Mean Squared Error (MSE): 0.0001891528527777834
# Root Mean Squared Error (RMSE): 0.013753285163108609
# R-squared (R²): -0.4823504712483391
# (0.010983773626311345,
#  0.0001891528527777834,
#  0.013753285163108609,
#  -0.4823504712483391)

# %% [markdown]
# # 4. Adding Technical Analysis Indicators
# As we can see from the above results, the model is not performing well. We can try to improve the model's performance by adding technical analysis indicators.

# %%
import pandas as pd
import numpy as np
import ta  # ta-lib or ta for calculating technical indicators
import xgboost as xgb
import combiner

# Initialize combiner instance
comb = combiner.combine_pvol_funda()

def add_technical_indicators(df):
    # Add SMA, EMA
    df['sma_20'] = ta.trend.sma_indicator(df['close'], window=20)
    df['sma_50'] = ta.trend.sma_indicator(df['close'], window=50)
    df['ema_20'] = ta.trend.ema_indicator(df['close'], window=20)
    
    # Add RSI, MACD
    df['rsi_14'] = ta.momentum.rsi(df['close'], window=14)
    df['macd'] = ta.trend.macd(df['close'])
    df['macd_signal'] = ta.trend.macd_signal(df['close'])

    # Add Bollinger Bands
    bollinger = ta.volatility.BollingerBands(df['close'], window=20)
    df['bb_upper'] = bollinger.bollinger_hband()
    df['bb_lower'] = bollinger.bollinger_lband()
    
    # Add Average True Range (ATR)
    df['atr_14'] = ta.volatility.average_true_range(df['high'], df['low'], df['close'], window=14)
    
    # Add On-Balance Volume (OBV)
    df['obv'] = ta.volume.on_balance_volume(df['close'], df['volume'])
    
    # Add Stochastic Oscillator (K, D)
    stoch = ta.momentum.stoch(df['high'], df['low'], df['close'], window=14, smooth_window=3)
    df['stoch_k'] = stoch
    df['stoch_d'] = ta.momentum.stoch_signal(df['high'], df['low'], df['close'], window=14, smooth_window=3)
    
    # Remove momentum since it was causing an error
    # Add Williams %R
    df['williams_r'] = ta.momentum.williams_r(df['high'], df['low'], df['close'], lbp=14)
    
    # Add Chaikin Money Flow (CMF)
    df['cmf'] = ta.volume.chaikin_money_flow(df['high'], df['low'], df['close'], df['volume'], window=20)
    
    return df

def prepdata(ticker, start_date, end_date):
    # Retrieve data for the ticker and date range
    data = comb.get_comb_data_from_postgresql(ticker, start_date, end_date)

    # Create a DataFrame
    df = pd.DataFrame(data)

    # Sort the data by date
    df['date'] = pd.to_datetime(df['date'])
    df = df.sort_values(by='date')

    # Add technical indicators
    df = add_technical_indicators(df)

    # Calculate log returns as the target variable
    df['log_return'] = np.log(df['close'] / df['close'].shift(1))

    # Drop rows with NaN values in log returns and technical indicators
    df = df.dropna()

    # Define the fundamental columns and technical indicators to use as features
    fundamental_columns = [
        'revenuePerShare', 'netIncomePerShare', 'operatingCashFlowPerShare', 'freeCashFlowPerShare', 
        'cashPerShare', 'bookValuePerShare', 'tangibleBookValuePerShare', 'shareholdersEquityPerShare', 
        'interestDebtPerShare', 'marketCap', 'enterpriseValue', 'peRatio', 'priceToSalesRatio', 
        'pocfratio', 'pfcfRatio', 'pbRatio', 'ptbRatio', 'evToSales', 'enterpriseValueOverEBITDA', 
        'evToOperatingCashFlow', 'evToFreeCashFlow', 'earningsYield', 'freeCashFlowYield', 
        'debtToEquity', 'debtToAssets', 'netDebtToEBITDA', 'currentRatio', 'interestCoverage', 
        'incomeQuality', 'dividendYield', 'payoutRatio', 'salesGeneralAndAdministrativeToRevenue', 
        'researchAndDdevelopementToRevenue', 'intangiblesToTotalAssets', 'capexToOperatingCashFlow', 
        'capexToRevenue', 'capexToDepreciation', 'stockBasedCompensationToRevenue', 'grahamNumber', 
        'roic', 'returnOnTangibleAssets', 'grahamNetNet', 'workingCapital', 'tangibleAssetValue', 
        'netCurrentAssetValue', 'investedCapital', 'averageReceivables', 'averagePayables', 
        'averageInventory', 'daysSalesOutstanding', 'daysPayablesOutstanding', 
        'daysOfInventoryOnHand', 'receivablesTurnover', 'payablesTurnover', 'inventoryTurnover', 
        'roe', 'capexPerShare'
    ]
    
    # Technical columns added
    technical_columns = [
        'sma_20', 'sma_50', 'ema_20', 'rsi_14', 'macd', 'macd_signal', 'bb_upper', 'bb_lower', 
        'atr_14', 'obv', 'stoch_k', 'stoch_d', 'williams_r', 'cmf'
    ]

    # Fill missing values in the fundamental columns using forward fill, followed by zeros if necessary
    df[fundamental_columns + technical_columns] = df[fundamental_columns + technical_columns].fillna(method='ffill').fillna(0)

    # Define features (X) and target (y)
    X = df[fundamental_columns + technical_columns]
    y = df['log_return']

    # Convert features into an XGBoost DMatrix
    dmat = xgb.DMatrix(X, label=y, missing=np.nan)

    return dmat, y, X

# Example of how to use the updated function
#ticker_list = ['AAPL']
for ticker in ticker_list:
    start_date = '2019-01-01'
    end_date = '2022-12-31'

    # Prepare the training data using log returns
    dtrain, y_train, X_train = prepdata(ticker, start_date, end_date)

    ''' Setting Test Data '''
    start_date = '2023-01-01'
    end_date = '2023-12-31'

    # Prepare the test data
    dtest, y_test, X_test = prepdata(ticker, start_date, end_date)
# Out:
# C:\Users\MP\AppData\Local\Temp\ipykernel_43164\304463306.py:91: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[fundamental_columns + technical_columns] = df[fundamental_columns + technical_columns].fillna(method='ffill').fillna(0)
# C:\Users\MP\AppData\Local\Temp\ipykernel_43164\304463306.py:91: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[fundamental_columns + technical_columns] = df[fundamental_columns + technical_columns].fillna(method='ffill').fillna(0)
# C:\Users\MP\AppData\Local\Temp\ipykernel_43164\304463306.py:91: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[fundamental_columns + technical_columns] = df[fundamental_columns + technical_columns].fillna(method='ffill').fillna(0)
# C:\Users\MP\AppData\Local\Temp\ipykernel_43164\304463306.py:91: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[fundamental_columns + technical_columns] = df[fundamental_columns + technical_columns].fillna(method='ffill').fillna(0)
# C:\Users\MP\AppData\Local\Temp\ipykernel_43164\304463306.py:91: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[fundamental_columns + technical_columns] = df[fundamental_columns + technical_columns].fillna(method='ffill').fillna(0)
# C:\Users\MP\AppData\Local\Temp\ipykernel_43164\304463306.py:91: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[fundamental_columns + technical_columns] = df[fundamental_columns + technical_columns].fillna(method='ffill').fillna(0)
# C:\Users\MP\AppData\Local\Temp\ipykernel_43164\304463306.py:91: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[fundamental_columns + technical_columns] = df[fundamental_columns + technical_columns].fillna(method='ffill').fillna(0)
# C:\Users\MP\AppData\Local\Temp\ipykernel_43164\304463306.py:91: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[fundamental_columns + technical_columns] = df[fundamental_columns + technical_columns].fillna(method='ffill').fillna(0)
# C:\Users\MP\AppData\Local\Temp\ipykernel_43164\304463306.py:91: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[fundamental_columns + technical_columns] = df[fundamental_columns + technical_columns].fillna(method='ffill').fillna(0)
# C:\Users\MP\AppData\Local\Temp\ipykernel_43164\304463306.py:91: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[fundamental_columns + technical_columns] = df[fundamental_columns + technical_columns].fillna(method='ffill').fillna(0)
# C:\Users\MP\AppData\Local\Temp\ipykernel_43164\304463306.py:91: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[fundamental_columns + technical_columns] = df[fundamental_columns + technical_columns].fillna(method='ffill').fillna(0)
# C:\Users\MP\AppData\Local\Temp\ipykernel_43164\304463306.py:91: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[fundamental_columns + technical_columns] = df[fundamental_columns + technical_columns].fillna(method='ffill').fillna(0)
# C:\Users\MP\AppData\Local\Temp\ipykernel_43164\304463306.py:91: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[fundamental_columns + technical_columns] = df[fundamental_columns + technical_columns].fillna(method='ffill').fillna(0)
# C:\Users\MP\AppData\Local\Temp\ipykernel_43164\304463306.py:91: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[fundamental_columns + technical_columns] = df[fundamental_columns + technical_columns].fillna(method='ffill').fillna(0)
# C:\Users\MP\AppData\Local\Temp\ipykernel_43164\304463306.py:91: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[fundamental_columns + technical_columns] = df[fundamental_columns + technical_columns].fillna(method='ffill').fillna(0)
# C:\Users\MP\AppData\Local\Temp\ipykernel_43164\304463306.py:91: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[fundamental_columns + technical_columns] = df[fundamental_columns + technical_columns].fillna(method='ffill').fillna(0)
# C:\Users\MP\AppData\Local\Temp\ipykernel_43164\304463306.py:91: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[fundamental_columns + technical_columns] = df[fundamental_columns + technical_columns].fillna(method='ffill').fillna(0)
# C:\Users\MP\AppData\Local\Temp\ipykernel_43164\304463306.py:91: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[fundamental_columns + technical_columns] = df[fundamental_columns + technical_columns].fillna(method='ffill').fillna(0)
# C:\Users\MP\AppData\Local\Temp\ipykernel_43164\304463306.py:91: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[fundamental_columns + technical_columns] = df[fundamental_columns + technical_columns].fillna(method='ffill').fillna(0)
# C:\Users\MP\AppData\Local\Temp\ipykernel_43164\304463306.py:91: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[fundamental_columns + technical_columns] = df[fundamental_columns + technical_columns].fillna(method='ffill').fillna(0)
# C:\Users\MP\AppData\Local\Temp\ipykernel_43164\304463306.py:91: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[fundamental_columns + technical_columns] = df[fundamental_columns + technical_columns].fillna(method='ffill').fillna(0)
# C:\Users\MP\AppData\Local\Temp\ipykernel_43164\304463306.py:91: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[fundamental_columns + technical_columns] = df[fundamental_columns + technical_columns].fillna(method='ffill').fillna(0)
# C:\Users\MP\AppData\Local\Temp\ipykernel_43164\304463306.py:91: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[fundamental_columns + technical_columns] = df[fundamental_columns + technical_columns].fillna(method='ffill').fillna(0)
# C:\Users\MP\AppData\Local\Temp\ipykernel_43164\304463306.py:91: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[fundamental_columns + technical_columns] = df[fundamental_columns + technical_columns].fillna(method='ffill').fillna(0)
# C:\Users\MP\AppData\Local\Temp\ipykernel_43164\304463306.py:91: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[fundamental_columns + technical_columns] = df[fundamental_columns + technical_columns].fillna(method='ffill').fillna(0)
# C:\Users\MP\AppData\Local\Temp\ipykernel_43164\304463306.py:91: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[fundamental_columns + technical_columns] = df[fundamental_columns + technical_columns].fillna(method='ffill').fillna(0)
# C:\Users\MP\AppData\Local\Temp\ipykernel_43164\304463306.py:91: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[fundamental_columns + technical_columns] = df[fundamental_columns + technical_columns].fillna(method='ffill').fillna(0)
# C:\Users\MP\AppData\Local\Temp\ipykernel_43164\304463306.py:91: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[fundamental_columns + technical_columns] = df[fundamental_columns + technical_columns].fillna(method='ffill').fillna(0)
# C:\Users\MP\AppData\Local\Temp\ipykernel_43164\304463306.py:91: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[fundamental_columns + technical_columns] = df[fundamental_columns + technical_columns].fillna(method='ffill').fillna(0)
# C:\Users\MP\AppData\Local\Temp\ipykernel_43164\304463306.py:91: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[fundamental_columns + technical_columns] = df[fundamental_columns + technical_columns].fillna(method='ffill').fillna(0)
# C:\Users\MP\AppData\Local\Temp\ipykernel_43164\304463306.py:91: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[fundamental_columns + technical_columns] = df[fundamental_columns + technical_columns].fillna(method='ffill').fillna(0)
# C:\Users\MP\AppData\Local\Temp\ipykernel_43164\304463306.py:91: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[fundamental_columns + technical_columns] = df[fundamental_columns + technical_columns].fillna(method='ffill').fillna(0)
# C:\Users\MP\AppData\Local\Temp\ipykernel_43164\304463306.py:91: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[fundamental_columns + technical_columns] = df[fundamental_columns + technical_columns].fillna(method='ffill').fillna(0)
# C:\Users\MP\AppData\Local\Temp\ipykernel_43164\304463306.py:91: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[fundamental_columns + technical_columns] = df[fundamental_columns + technical_columns].fillna(method='ffill').fillna(0)
# C:\Users\MP\AppData\Local\Temp\ipykernel_43164\304463306.py:91: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[fundamental_columns + technical_columns] = df[fundamental_columns + technical_columns].fillna(method='ffill').fillna(0)
# C:\Users\MP\AppData\Local\Temp\ipykernel_43164\304463306.py:91: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[fundamental_columns + technical_columns] = df[fundamental_columns + technical_columns].fillna(method='ffill').fillna(0)
# C:\Users\MP\AppData\Local\Temp\ipykernel_43164\304463306.py:91: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[fundamental_columns + technical_columns] = df[fundamental_columns + technical_columns].fillna(method='ffill').fillna(0)
# C:\Users\MP\AppData\Local\Temp\ipykernel_43164\304463306.py:91: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[fundamental_columns + technical_columns] = df[fundamental_columns + technical_columns].fillna(method='ffill').fillna(0)
# C:\Users\MP\AppData\Local\Temp\ipykernel_43164\304463306.py:91: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[fundamental_columns + technical_columns] = df[fundamental_columns + technical_columns].fillna(method='ffill').fillna(0)
# C:\Users\MP\AppData\Local\Temp\ipykernel_43164\304463306.py:91: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[fundamental_columns + technical_columns] = df[fundamental_columns + technical_columns].fillna(method='ffill').fillna(0)
# C:\Users\MP\AppData\Local\Temp\ipykernel_43164\304463306.py:91: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[fundamental_columns + technical_columns] = df[fundamental_columns + technical_columns].fillna(method='ffill').fillna(0)
# C:\Users\MP\AppData\Local\Temp\ipykernel_43164\304463306.py:91: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[fundamental_columns + technical_columns] = df[fundamental_columns + technical_columns].fillna(method='ffill').fillna(0)
# C:\Users\MP\AppData\Local\Temp\ipykernel_43164\304463306.py:91: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[fundamental_columns + technical_columns] = df[fundamental_columns + technical_columns].fillna(method='ffill').fillna(0)
# C:\Users\MP\AppData\Local\Temp\ipykernel_43164\304463306.py:91: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[fundamental_columns + technical_columns] = df[fundamental_columns + technical_columns].fillna(method='ffill').fillna(0)
# C:\Users\MP\AppData\Local\Temp\ipykernel_43164\304463306.py:91: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[fundamental_columns + technical_columns] = df[fundamental_columns + technical_columns].fillna(method='ffill').fillna(0)
# C:\Users\MP\AppData\Local\Temp\ipykernel_43164\304463306.py:91: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[fundamental_columns + technical_columns] = df[fundamental_columns + technical_columns].fillna(method='ffill').fillna(0)
# C:\Users\MP\AppData\Local\Temp\ipykernel_43164\304463306.py:91: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[fundamental_columns + technical_columns] = df[fundamental_columns + technical_columns].fillna(method='ffill').fillna(0)
# C:\Users\MP\AppData\Local\Temp\ipykernel_43164\304463306.py:91: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[fundamental_columns + technical_columns] = df[fundamental_columns + technical_columns].fillna(method='ffill').fillna(0)
# C:\Users\MP\AppData\Local\Temp\ipykernel_43164\304463306.py:91: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[fundamental_columns + technical_columns] = df[fundamental_columns + technical_columns].fillna(method='ffill').fillna(0)
# C:\Users\MP\AppData\Local\Temp\ipykernel_43164\304463306.py:91: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[fundamental_columns + technical_columns] = df[fundamental_columns + technical_columns].fillna(method='ffill').fillna(0)
# C:\Users\MP\AppData\Local\Temp\ipykernel_43164\304463306.py:91: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[fundamental_columns + technical_columns] = df[fundamental_columns + technical_columns].fillna(method='ffill').fillna(0)
# C:\Users\MP\AppData\Local\Temp\ipykernel_43164\304463306.py:91: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[fundamental_columns + technical_columns] = df[fundamental_columns + technical_columns].fillna(method='ffill').fillna(0)
# C:\Users\MP\AppData\Local\Temp\ipykernel_43164\304463306.py:91: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[fundamental_columns + technical_columns] = df[fundamental_columns + technical_columns].fillna(method='ffill').fillna(0)
# C:\Users\MP\AppData\Local\Temp\ipykernel_43164\304463306.py:91: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[fundamental_columns + technical_columns] = df[fundamental_columns + technical_columns].fillna(method='ffill').fillna(0)
# C:\Users\MP\AppData\Local\Temp\ipykernel_43164\304463306.py:91: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[fundamental_columns + technical_columns] = df[fundamental_columns + technical_columns].fillna(method='ffill').fillna(0)
# C:\Users\MP\AppData\Local\Temp\ipykernel_43164\304463306.py:91: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[fundamental_columns + technical_columns] = df[fundamental_columns + technical_columns].fillna(method='ffill').fillna(0)
# C:\Users\MP\AppData\Local\Temp\ipykernel_43164\304463306.py:91: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[fundamental_columns + technical_columns] = df[fundamental_columns + technical_columns].fillna(method='ffill').fillna(0)
# C:\Users\MP\AppData\Local\Temp\ipykernel_43164\304463306.py:91: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[fundamental_columns + technical_columns] = df[fundamental_columns + technical_columns].fillna(method='ffill').fillna(0)
# C:\Users\MP\AppData\Local\Temp\ipykernel_43164\304463306.py:91: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[fundamental_columns + technical_columns] = df[fundamental_columns + technical_columns].fillna(method='ffill').fillna(0)
# C:\Users\MP\AppData\Local\Temp\ipykernel_43164\304463306.py:91: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[fundamental_columns + technical_columns] = df[fundamental_columns + technical_columns].fillna(method='ffill').fillna(0)

# %%
''' 
Choose an appropriate objective function (e.g., reg:squarederror for regression, binary:logistic for classification).
'''
# Load data
#dtrain = xgb.DMatrix(X_train, label=y_train)
#dtest = xgb.DMatrix(X_test, label=y_test)

# Set parameters
params = {
    'objective': 'reg:squarederror',  # Regression task
    'eval_metric': 'rmse',            # Root mean square error
    'max_depth': 5,                   # Maximum depth of trees
    'learning_rate': 0.1,             # Step size shrinkage
    'n_estimators': 100               # Number of boosting rounds
}

# Train the model
model = xgb.train(params, dtrain, num_boost_round=100)

# Make predictions
y_pred = model.predict(dtest)
# Out:
# c:\Users\MP\anaconda3\envs\algo\lib\site-packages\xgboost\core.py:160: UserWarning: [18:13:17] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0b3782d1791676daf-1\xgboost\xgboost-ci-windows\src\learner.cc:742:
# Parameters: { "n_estimators" } are not used.
#
#   warnings.warn(smsg, UserWarning)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

def evaluate_model(model, dtest, y_test):
    # Predict using the trained model
    y_pred = model.predict(dtest)

    # Calculate evaluation metrics
    mae = mean_absolute_error(y_test, y_pred)
    mse = mean_squared_error(y_test, y_pred)
    rmse = np.sqrt(mse)
    r2 = r2_score(y_test, y_pred)

    # Print results
    print(f"Mean Absolute Error (MAE): {mae}")
    print(f"Mean Squared Error (MSE): {mse}")
    print(f"Root Mean Squared Error (RMSE): {rmse}")
    print(f"R-squared (R²): {r2}")
    
    return mae, mse, rmse, r2

# Assuming your trained XGBoost model is `xgb_model`
evaluate_model(model, dtest, y_test)
# Out:
# Mean Absolute Error (MAE): 0.00668469744058219
# Mean Squared Error (MSE): 7.53573063892605e-05
# Root Mean Squared Error (RMSE): 0.008680858620508717
# R-squared (R²): 0.263906519976159
# (0.00668469744058219,
#  7.53573063892605e-05,
#  0.008680858620508717,
#  0.263906519976159)

# %%
# Plot feature importance
xgb.plot_importance(model)
# Out:
# <Axes: title={'center': 'Feature importance'}, xlabel='F score', ylabel='Features'>

# %%
import shap
import xgboost as xgb

# Train the XGBoost model
params = {
    'objective': 'reg:squarederror', 
    'eval_metric': 'rmse'
}

# Train the model on the prepared data
xgb_model = xgb.train(params=params, dtrain=dtrain, num_boost_round=100)

# Create the SHAP explainer based on your XGBoost model
explainer = shap.TreeExplainer(xgb_model)

# Get SHAP values for the test data
shap_values = explainer.shap_values(X_test)

# Visualize the feature importance using SHAP
shap.summary_plot(shap_values, X_test, feature_names=X_test.columns)

# %%
# SHAP dependence plot for a specific feature (e.g., 'sma_20')
shap.dependence_plot('sma_20', shap_values, X_test)

# %% [markdown]
# # Hyper Parameter Tuning

# %%
from sklearn.model_selection import GridSearchCV
from xgboost import XGBRegressor

# Define the model
xgb_regressor = XGBRegressor()

# Define the parameter grid for hyperparameter tuning
param_grid = {
    'learning_rate': [0.01, 0.1, 0.2],
    'max_depth': [3, 5, 7],
    'n_estimators': [100, 200, 300],
    'subsample': [0.7, 0.8, 1.0],
    'colsample_bytree': [0.7, 0.8, 1.0]
}

# Set up GridSearchCV with 5-fold cross-validation
grid_search = GridSearchCV(estimator=xgb_regressor, param_grid=param_grid, cv=5, scoring='neg_mean_squared_error', verbose=1)

# Fit the model with the training data (X_train and y_train)
grid_search.fit(X_train, y_train)

# Print the best parameters and best score
print(f"Best Parameters: {grid_search.best_params_}")
print(f"Best Score: {grid_search.best_score_}")
# Out:
# Fitting 5 folds for each of 243 candidates, totalling 1215 fits
# Best Parameters: {'colsample_bytree': 0.7, 'learning_rate': 0.2, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.8}
# Best Score: -0.0018852630693048955

# %%
from xgboost import XGBRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

# Instantiate the XGBoost model using the best parameters found
best_params = {
    'colsample_bytree': 0.7,
    'learning_rate': 0.2,
    'max_depth': 3,
    'n_estimators': 100,
    'subsample': 0.8
}

# Initialize the XGBoost model with the best parameters
best_model = XGBRegressor(**best_params)

# Prepare the data for MSFT (or any other ticker)
ticker = 'AAPL'
start_date = '2019-01-01'
end_date = '2022-12-31'

# Prepare the training data for MSFT
dtrain, y_train, X_train = prepdata(ticker, start_date, end_date)

# Fit the model with MSFT training data
best_model.fit(X_train, y_train)

# Prepare test data for MSFT
start_date = '2023-01-01'
end_date = '2023-12-31'
dtest, y_test, X_test = prepdata(ticker, start_date, end_date)

# Make predictions on the test data
y_pred = best_model.predict(X_test)

# Compute performance metrics
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

# Print evaluation metrics
print(f"Mean Absolute Error (MAE): {mae}")
print(f"Mean Squared Error (MSE): {mse}")
print(f"Root Mean Squared Error (RMSE): {rmse}")
print(f"R-squared (R²): {r2}")
# Out:
# C:\Users\MP\AppData\Local\Temp\ipykernel_560\1618965653.py:91: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[fundamental_columns + technical_columns] = df[fundamental_columns + technical_columns].fillna(method='ffill').fillna(0)
# Mean Absolute Error (MAE): 0.008560583235210752
# Mean Squared Error (MSE): 0.00011021999239229987
# Root Mean Squared Error (RMSE): 0.010498570969055735
# R-squared (R²): -0.07663372877419894
# C:\Users\MP\AppData\Local\Temp\ipykernel_560\1618965653.py:91: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[fundamental_columns + technical_columns] = df[fundamental_columns + technical_columns].fillna(method='ffill').fillna(0)

# %%
''' Optimizing for R2 '''
from sklearn.model_selection import GridSearchCV
from xgboost import XGBRegressor

# Define the model
xgb_regressor = XGBRegressor()

# Define the parameter grid for hyperparameter tuning
param_grid = {
    'learning_rate': [0.01, 0.1, 0.2],
    'max_depth': [3, 5, 7],
    'n_estimators': [100, 200, 300],
    'subsample': [0.7, 0.8, 1.0],
    'colsample_bytree': [0.7, 0.8, 1.0],
    'alpha': [0, 0.1, 0.5],  # L1 regularization
    'lambda': [0, 0.1, 0.5]  # L2 regularization
}

# Set up GridSearchCV with 5-fold cross-validation
# Change the scoring to 'r2' to optimize for R-squared
grid_search = GridSearchCV(estimator=xgb_regressor, param_grid=param_grid, cv=5, scoring='r2', verbose=1)

# Fit the model with the training data (X_train and y_train)
grid_search.fit(X_train, y_train)

# Print the best parameters and best R-squared score
print(f"Best Parameters: {grid_search.best_params_}")
print(f"Best R² Score: {grid_search.best_score_}")
# Out:
# Fitting 5 folds for each of 243 candidates, totalling 1215 fits
# Best Parameters: {'colsample_bytree': 0.7, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100, 'subsample': 0.8}
# Best R² Score: 0.5087879809878835

# %%
from xgboost import XGBRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

# Best hyperparameters from the latest GridSearchCV
best_params = {
    'colsample_bytree': 0.7,
    'learning_rate': 0.1,
    'max_depth': 5,
    'n_estimators': 100,
    'subsample': 0.8
}

# Initialize the XGBoost model with the best parameters
best_model = XGBRegressor(**best_params)

# Apply the model to a new ticker (MSFT)
ticker = 'MSFT'
start_date = '2019-01-01'
end_date = '2022-12-31'

# Prepare the training data for MSFT
dtrain, y_train, X_train = prepdata(ticker, start_date, end_date)

# Fit the model with MSFT training data
best_model.fit(X_train, y_train)

# Prepare test data for MSFT
start_date = '2023-01-01'
end_date = '2023-12-31'
dtest, y_test, X_test = prepdata(ticker, start_date, end_date)

# Make predictions on the test data
y_pred = best_model.predict(X_test)

# Compute performance metrics (MAE, MSE, RMSE, R²)
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

# Print evaluation metrics for MSFT
print(f"Performance on MSFT:")
print(f"Mean Absolute Error (MAE): {mae}")
print(f"Mean Squared Error (MSE): {mse}")
print(f"Root Mean Squared Error (RMSE): {rmse}")
print(f"R-squared (R²): {r2}")
# Out:
# C:\Users\MP\AppData\Local\Temp\ipykernel_560\1618965653.py:91: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[fundamental_columns + technical_columns] = df[fundamental_columns + technical_columns].fillna(method='ffill').fillna(0)
# Performance on MSFT:
# Mean Absolute Error (MAE): 0.007042573456450433
# Mean Squared Error (MSE): 8.794344697925172e-05
# Root Mean Squared Error (RMSE): 0.009377816749076073
# R-squared (R²): 0.5948364355067517
# C:\Users\MP\AppData\Local\Temp\ipykernel_560\1618965653.py:91: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[fundamental_columns + technical_columns] = df[fundamental_columns + technical_columns].fillna(method='ffill').fillna(0)

# %%
tickers = ['AAPL', 'MSFT', 'GOOG', 'AMZN']

# Iterate through each ticker and evaluate the model
for ticker in tickers:
    start_date = '2019-01-01'
    end_date = '2022-12-31'

    # Prepare the data for each ticker
    dtrain, y_train, X_train = prepdata(ticker, start_date, end_date)

    # Predict using the best model
    y_pred = best_model.predict(X_train)

    # Evaluate the model performance
    mae = mean_absolute_error(y_train, y_pred)
    mse = mean_squared_error(y_train, y_pred)
    rmse = np.sqrt(mse)
    r2 = r2_score(y_train, y_pred)

    print(f"Performance on {ticker}:")
    print(f"MAE: {mae}")
    print(f"MSE: {mse}")
    print(f"RMSE: {rmse}")
    print(f"R-squared (R²): {r2}")
    print('---')
# Out:
# C:\Users\MP\AppData\Local\Temp\ipykernel_560\1618965653.py:91: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[fundamental_columns + technical_columns] = df[fundamental_columns + technical_columns].fillna(method='ffill').fillna(0)
# Performance on AAPL:
# MAE: 0.011815849780557795
# MSE: 0.0020073040532679453
# RMSE: 0.04480294692615593
# R-squared (R²): 0.1640217728011938
# ---
# C:\Users\MP\AppData\Local\Temp\ipykernel_560\1618965653.py:91: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[fundamental_columns + technical_columns] = df[fundamental_columns + technical_columns].fillna(method='ffill').fillna(0)
# Performance on MSFT:
# MAE: 0.003469760827902138
# MSE: 1.9977670619013926e-05
# RMSE: 0.0044696387571048655
# R-squared (R²): 0.9472548494335827
# ---
# C:\Users\MP\AppData\Local\Temp\ipykernel_560\1618965653.py:91: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[fundamental_columns + technical_columns] = df[fundamental_columns + technical_columns].fillna(method='ffill').fillna(0)
# Performance on GOOG:
# MAE: 0.01139310207426117
# MSE: 0.0002195783143241733
# RMSE: 0.014818175134751692
# R-squared (R²): -1.3315742646933635
# ---
# Performance on AMZN:
# MAE: 0.015429502293087703
# MSE: 0.00925944487703979
# RMSE: 0.09622600935838392
# R-squared (R²): 0.051397088444014916
# ---
# C:\Users\MP\AppData\Local\Temp\ipykernel_560\1618965653.py:91: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[fundamental_columns + technical_columns] = df[fundamental_columns + technical_columns].fillna(method='ffill').fillna(0)

# %%
from sklearn.model_selection import TimeSeriesSplit, GridSearchCV
from xgboost import XGBRegressor

# Combine training data for multiple tickers
tickers = ['AAPL', 'MSFT', 'GOOG', 'AMZN']
X_combined = []
y_combined = []

for ticker in tickers:
    dtrain, y_train, X_train = prepdata(ticker, '2019-01-01', '2022-12-31')
    X_combined.append(X_train)
    y_combined.append(y_train)

X_combined = pd.concat(X_combined)
y_combined = np.concatenate(y_combined)

# Initialize model and parameter grid
xgb_regressor = XGBRegressor()

param_grid = {
    'learning_rate': [0.01, 0.1],
    'max_depth': [3, 5],
    'n_estimators': [100, 200],
    'subsample': [0.8],
    'colsample_bytree': [0.7, 0.8],
    'alpha': [0.1],
    'lambda': [0.1]
}

# Use TimeSeriesSplit for time-based cross-validation
tscv = TimeSeriesSplit(n_splits=5)

# Perform GridSearchCV with cross-validation
grid_search = GridSearchCV(estimator=xgb_regressor, param_grid=param_grid, cv=tscv, scoring='r2')
grid_search.fit(X_combined, y_combined)

# Print the best parameters and R² score
print(f"Best Parameters: {grid_search.best_params_}")
print(f"Best R² Score: {grid_search.best_score_}")
# Out:
# C:\Users\MP\AppData\Local\Temp\ipykernel_560\1618965653.py:91: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[fundamental_columns + technical_columns] = df[fundamental_columns + technical_columns].fillna(method='ffill').fillna(0)
# C:\Users\MP\AppData\Local\Temp\ipykernel_560\1618965653.py:91: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[fundamental_columns + technical_columns] = df[fundamental_columns + technical_columns].fillna(method='ffill').fillna(0)
# C:\Users\MP\AppData\Local\Temp\ipykernel_560\1618965653.py:91: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[fundamental_columns + technical_columns] = df[fundamental_columns + technical_columns].fillna(method='ffill').fillna(0)
# C:\Users\MP\AppData\Local\Temp\ipykernel_560\1618965653.py:91: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[fundamental_columns + technical_columns] = df[fundamental_columns + technical_columns].fillna(method='ffill').fillna(0)
# Best Parameters: {'alpha': 0.1, 'colsample_bytree': 0.7, 'lambda': 0.1, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100, 'subsample': 0.8}
# Best R² Score: -0.8918863538541283

# %%
from sklearn.model_selection import TimeSeriesSplit, GridSearchCV
from xgboost import XGBRegressor
from tqdm import tqdm  # Import tqdm for progress bar

# Combine training data for multiple tickers
tickers = ticker_list #tickerlist defined at the top of file
X_combined = []
y_combined = []

# Loop through tickers with progress bar
for ticker in tqdm(tickers, desc="Processing tickers"):
    dtrain, y_train, X_train = prepdata(ticker, '2019-01-01', '2022-12-31')
    X_combined.append(X_train)
    y_combined.append(y_train)

X_combined = pd.concat(X_combined)
y_combined = np.concatenate(y_combined)

# Initialize model and parameter grid
xgb_regressor = XGBRegressor()

param_grid = {
    'learning_rate': [0.01, 0.1],
    'max_depth': [3, 5],
    'n_estimators': [100, 200],
    'subsample': [0.8],
    'colsample_bytree': [0.7, 0.8],
    'alpha': [0.1],
    'lambda': [0.1]
}

# Use TimeSeriesSplit for time-based cross-validation
tscv = TimeSeriesSplit(n_splits=5)

# Perform GridSearchCV with cross-validation
grid_search = GridSearchCV(estimator=xgb_regressor, param_grid=param_grid, cv=tscv, scoring='r2', verbose=1)
grid_search.fit(X_combined, y_combined)

# Print the best parameters and R² score
print(f"Best Parameters: {grid_search.best_params_}")
print(f"Best R² Score: {grid_search.best_score_}")
# Out:
# Processing tickers:   0%|          | 0/30 [00:00<?, ?it/s]C:\Users\MP\AppData\Local\Temp\ipykernel_43164\304463306.py:91: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[fundamental_columns + technical_columns] = df[fundamental_columns + technical_columns].fillna(method='ffill').fillna(0)
# Processing tickers:   3%|▎         | 1/30 [00:00<00:06,  4.45it/s]C:\Users\MP\AppData\Local\Temp\ipykernel_43164\304463306.py:91: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[fundamental_columns + technical_columns] = df[fundamental_columns + technical_columns].fillna(method='ffill').fillna(0)
# Processing tickers:   7%|▋         | 2/30 [00:00<00:06,  4.37it/s]C:\Users\MP\AppData\Local\Temp\ipykernel_43164\304463306.py:91: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[fundamental_columns + technical_columns] = df[fundamental_columns + technical_columns].fillna(method='ffill').fillna(0)
# Processing tickers:  10%|█         | 3/30 [00:00<00:07,  3.85it/s]C:\Users\MP\AppData\Local\Temp\ipykernel_43164\304463306.py:91: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[fundamental_columns + technical_columns] = df[fundamental_columns + technical_columns].fillna(method='ffill').fillna(0)
# Processing tickers:  13%|█▎        | 4/30 [00:00<00:06,  4.05it/s]C:\Users\MP\AppData\Local\Temp\ipykernel_43164\304463306.py:91: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[fundamental_columns + technical_columns] = df[fundamental_columns + technical_columns].fillna(method='ffill').fillna(0)
# Processing tickers:  17%|█▋        | 5/30 [00:01<00:06,  3.96it/s]C:\Users\MP\AppData\Local\Temp\ipykernel_43164\304463306.py:91: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[fundamental_columns + technical_columns] = df[fundamental_columns + technical_columns].fillna(method='ffill').fillna(0)
# Processing tickers:  20%|██        | 6/30 [00:01<00:06,  3.79it/s]C:\Users\MP\AppData\Local\Temp\ipykernel_43164\304463306.py:91: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[fundamental_columns + technical_columns] = df[fundamental_columns + technical_columns].fillna(method='ffill').fillna(0)
# Processing tickers:  23%|██▎       | 7/30 [00:01<00:05,  4.02it/s]C:\Users\MP\AppData\Local\Temp\ipykernel_43164\304463306.py:91: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[fundamental_columns + technical_columns] = df[fundamental_columns + technical_columns].fillna(method='ffill').fillna(0)
# Processing tickers:  27%|██▋       | 8/30 [00:01<00:05,  4.31it/s]C:\Users\MP\AppData\Local\Temp\ipykernel_43164\304463306.py:91: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[fundamental_columns + technical_columns] = df[fundamental_columns + technical_columns].fillna(method='ffill').fillna(0)
# Processing tickers:  30%|███       | 9/30 [00:02<00:06,  3.26it/s]C:\Users\MP\AppData\Local\Temp\ipykernel_43164\304463306.py:91: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[fundamental_columns + technical_columns] = df[fundamental_columns + technical_columns].fillna(method='ffill').fillna(0)
# Processing tickers:  33%|███▎      | 10/30 [00:02<00:05,  3.47it/s]C:\Users\MP\AppData\Local\Temp\ipykernel_43164\304463306.py:91: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[fundamental_columns + technical_columns] = df[fundamental_columns + technical_columns].fillna(method='ffill').fillna(0)
# Processing tickers:  37%|███▋      | 11/30 [00:02<00:05,  3.68it/s]C:\Users\MP\AppData\Local\Temp\ipykernel_43164\304463306.py:91: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[fundamental_columns + technical_columns] = df[fundamental_columns + technical_columns].fillna(method='ffill').fillna(0)
# Processing tickers:  40%|████      | 12/30 [00:03<00:05,  3.55it/s]C:\Users\MP\AppData\Local\Temp\ipykernel_43164\304463306.py:91: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[fundamental_columns + technical_columns] = df[fundamental_columns + technical_columns].fillna(method='ffill').fillna(0)
# Processing tickers:  43%|████▎     | 13/30 [00:03<00:04,  3.62it/s]C:\Users\MP\AppData\Local\Temp\ipykernel_43164\304463306.py:91: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[fundamental_columns + technical_columns] = df[fundamental_columns + technical_columns].fillna(method='ffill').fillna(0)
# Processing tickers:  47%|████▋     | 14/30 [00:03<00:04,  3.58it/s]C:\Users\MP\AppData\Local\Temp\ipykernel_43164\304463306.py:91: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[fundamental_columns + technical_columns] = df[fundamental_columns + technical_columns].fillna(method='ffill').fillna(0)
# Processing tickers:  50%|█████     | 15/30 [00:04<00:04,  3.54it/s]C:\Users\MP\AppData\Local\Temp\ipykernel_43164\304463306.py:91: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[fundamental_columns + technical_columns] = df[fundamental_columns + technical_columns].fillna(method='ffill').fillna(0)
# Processing tickers:  53%|█████▎    | 16/30 [00:04<00:03,  3.59it/s]C:\Users\MP\AppData\Local\Temp\ipykernel_43164\304463306.py:91: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[fundamental_columns + technical_columns] = df[fundamental_columns + technical_columns].fillna(method='ffill').fillna(0)
# Processing tickers:  57%|█████▋    | 17/30 [00:04<00:03,  3.56it/s]C:\Users\MP\AppData\Local\Temp\ipykernel_43164\304463306.py:91: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[fundamental_columns + technical_columns] = df[fundamental_columns + technical_columns].fillna(method='ffill').fillna(0)
# Processing tickers:  60%|██████    | 18/30 [00:04<00:03,  3.74it/s]C:\Users\MP\AppData\Local\Temp\ipykernel_43164\304463306.py:91: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[fundamental_columns + technical_columns] = df[fundamental_columns + technical_columns].fillna(method='ffill').fillna(0)
# Processing tickers:  63%|██████▎   | 19/30 [00:05<00:02,  3.93it/s]C:\Users\MP\AppData\Local\Temp\ipykernel_43164\304463306.py:91: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[fundamental_columns + technical_columns] = df[fundamental_columns + technical_columns].fillna(method='ffill').fillna(0)
# Processing tickers:  67%|██████▋   | 20/30 [00:05<00:02,  4.17it/s]C:\Users\MP\AppData\Local\Temp\ipykernel_43164\304463306.py:91: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[fundamental_columns + technical_columns] = df[fundamental_columns + technical_columns].fillna(method='ffill').fillna(0)
# Processing tickers:  70%|███████   | 21/30 [00:05<00:02,  4.35it/s]C:\Users\MP\AppData\Local\Temp\ipykernel_43164\304463306.py:91: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[fundamental_columns + technical_columns] = df[fundamental_columns + technical_columns].fillna(method='ffill').fillna(0)
# Processing tickers:  73%|███████▎  | 22/30 [00:05<00:01,  4.26it/s]C:\Users\MP\AppData\Local\Temp\ipykernel_43164\304463306.py:91: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[fundamental_columns + technical_columns] = df[fundamental_columns + technical_columns].fillna(method='ffill').fillna(0)
# Processing tickers:  77%|███████▋  | 23/30 [00:05<00:01,  4.02it/s]C:\Users\MP\AppData\Local\Temp\ipykernel_43164\304463306.py:91: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[fundamental_columns + technical_columns] = df[fundamental_columns + technical_columns].fillna(method='ffill').fillna(0)
# Processing tickers:  80%|████████  | 24/30 [00:06<00:01,  3.74it/s]C:\Users\MP\AppData\Local\Temp\ipykernel_43164\304463306.py:91: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[fundamental_columns + technical_columns] = df[fundamental_columns + technical_columns].fillna(method='ffill').fillna(0)
# Processing tickers:  83%|████████▎ | 25/30 [00:06<00:01,  3.33it/s]C:\Users\MP\AppData\Local\Temp\ipykernel_43164\304463306.py:91: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[fundamental_columns + technical_columns] = df[fundamental_columns + technical_columns].fillna(method='ffill').fillna(0)
# Processing tickers:  87%|████████▋ | 26/30 [00:06<00:01,  3.34it/s]C:\Users\MP\AppData\Local\Temp\ipykernel_43164\304463306.py:91: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[fundamental_columns + technical_columns] = df[fundamental_columns + technical_columns].fillna(method='ffill').fillna(0)
# Processing tickers:  90%|█████████ | 27/30 [00:07<00:00,  3.40it/s]C:\Users\MP\AppData\Local\Temp\ipykernel_43164\304463306.py:91: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[fundamental_columns + technical_columns] = df[fundamental_columns + technical_columns].fillna(method='ffill').fillna(0)
# Processing tickers:  93%|█████████▎| 28/30 [00:07<00:00,  3.71it/s]C:\Users\MP\AppData\Local\Temp\ipykernel_43164\304463306.py:91: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[fundamental_columns + technical_columns] = df[fundamental_columns + technical_columns].fillna(method='ffill').fillna(0)
# Processing tickers:  97%|█████████▋| 29/30 [00:07<00:00,  3.65it/s]C:\Users\MP\AppData\Local\Temp\ipykernel_43164\304463306.py:91: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[fundamental_columns + technical_columns] = df[fundamental_columns + technical_columns].fillna(method='ffill').fillna(0)
# Processing tickers: 100%|██████████| 30/30 [00:07<00:00,  3.76it/s]
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# Best Parameters: {'alpha': 0.1, 'colsample_bytree': 0.8, 'lambda': 0.1, 'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 200, 'subsample': 0.8}
# Best R² Score: 0.3946600827811203

# %%
import joblib

# Save the best model
best_model = grid_search.best_estimator_
joblib.dump(best_model, 'xgb_best_model.pkl')
# Out:
# ['xgb_best_model.pkl']

# %%
# Load the saved model
best_model = joblib.load('xgb_best_model.pkl')

# %%
# Test the model on new tickers
#new_tickers = ['MSFT', 'GOOG', 'AMZN']  # Example tickers

for ticker in ticker_list:
    # Prepare data for the new ticker
    dtrain, y_train, X_train = prepdata(ticker, '2019-01-01', '2022-12-31')
    
    # Use the saved model to make predictions
    y_pred = best_model.predict(X_train)
    
    # Evaluate model performance
    from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
    
    mae = mean_absolute_error(y_train, y_pred)
    mse = mean_squared_error(y_train, y_pred)
    r2 = r2_score(y_train, y_pred)
    
    print(f"Performance on {ticker}:")
    print(f"MAE: {mae}")
    print(f"MSE: {mse}")
    print(f"R²: {r2}")
    print('---')
# Out:
# C:\Users\MP\AppData\Local\Temp\ipykernel_43164\304463306.py:91: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[fundamental_columns + technical_columns] = df[fundamental_columns + technical_columns].fillna(method='ffill').fillna(0)
# Performance on AAPL:
# MAE: 0.010657280699010603
# MSE: 0.00037526202591214663
# R²: 0.8437153142562837
# ---
# C:\Users\MP\AppData\Local\Temp\ipykernel_43164\304463306.py:91: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[fundamental_columns + technical_columns] = df[fundamental_columns + technical_columns].fillna(method='ffill').fillna(0)
# Performance on MSFT:
# MAE: 0.008590097771808674
# MSE: 0.00016334083034455678
# R²: 0.5687466845124849
# ---
# C:\Users\MP\AppData\Local\Temp\ipykernel_43164\304463306.py:91: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[fundamental_columns + technical_columns] = df[fundamental_columns + technical_columns].fillna(method='ffill').fillna(0)
# Performance on NVDA:
# MAE: 0.0176413149906086
# MSE: 0.0009030613447724581
# R²: 0.7152710799489919
# ---
# C:\Users\MP\AppData\Local\Temp\ipykernel_43164\304463306.py:91: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[fundamental_columns + technical_columns] = df[fundamental_columns + technical_columns].fillna(method='ffill').fillna(0)
# Performance on AMZN:
# MAE: 0.011795866266487055
# MSE: 0.00097014227203317
# R²: 0.9006117757495185
# ---
# C:\Users\MP\AppData\Local\Temp\ipykernel_43164\304463306.py:91: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[fundamental_columns + technical_columns] = df[fundamental_columns + technical_columns].fillna(method='ffill').fillna(0)
# Performance on TSLA:
# MAE: 0.023616065903998035
# MSE: 0.0013066846762331264
# R²: 0.7602206227971915
# ---
# C:\Users\MP\AppData\Local\Temp\ipykernel_43164\304463306.py:91: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[fundamental_columns + technical_columns] = df[fundamental_columns + technical_columns].fillna(method='ffill').fillna(0)
#